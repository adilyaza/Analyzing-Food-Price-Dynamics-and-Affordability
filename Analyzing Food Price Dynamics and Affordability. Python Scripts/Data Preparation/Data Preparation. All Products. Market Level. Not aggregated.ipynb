# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import pearsonr
import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import scale
from pylab import rcParams
import matplotlib.ticker as mt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %% [markdown]
# <a id='top'></a>
# # World Food Programme: food price and affordability analysis
# #### Data understanding and preparation
# ### [World Food Programme: Commodity prices in 99 countries ](https://data.humdata.org/dataset?dataseries_name=WFP+-+Food+Prices)
#
# #### [Data understanding](#understanding)
#
# #### [Data wrangling](#wrangling)
#
# #### [Data cleaning](#cleaning)
#
# #### [Distribution analysis](#distribution)

# %% [markdown]
# <a id='understanding'></a>
# ### Data understanding
# [Back to top](#top)

# %%
path=r'C:\Users\frauz\Documents\Python Projects\Final Project\Data\Data Prepared' #creating a path

# %%
df_food=pd.read_pickle(os.path.join(path,'global_food_prices.pkl')) #importing data

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3542751 entries, 0 to 3542750
# Data columns (total 16 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   index      int64
#  1   date       object
#  2   admin1     object
#  3   admin2     object
#  4   market     object
#  5   latitude   float64
#  6   longitude  float64
#  7   category   object
#  8   commodity  object
#  9   unit       object
#  10  priceflag  object
#  11  pricetype  object
#  12  currency   object
#  13  price      float64
#  14  usdprice   float64
#  15  iso        object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 432.5+ MB

# %%
# Removing an extra index column

df_food.drop(columns='index', inplace=True)

# %%
df_food.index
# Out:
# RangeIndex(start=0, stop=3542751, step=1)

# %%
df_food.describe().apply(lambda s: s.apply('{0:.5f}'.format)) # basic statistics
# Out:
#             latitude      longitude           price       usdprice
# count  3515876.00000  3515876.00000   3542751.00000  3538809.00000
# mean        13.59380       37.25309      6791.21714       13.54921
# std         16.61378       46.51168     83441.09058     1075.81118
# min        -34.61000     -107.38600         0.00000        0.00000
# 25%          1.72680        8.68138         1.54000        0.16780
# 50%         12.32634       34.25617       130.50000        0.74070
# 75%         27.65266       71.55583      1200.00000        1.99500
# max         59.93000      179.37736  17250000.00000   599999.99110

# %%
df_food.head()
# Out:
#          date      admin1          admin2    market   latitude  longitude  \
# 0  2000-01-15  Badakhshan       Faiz Abad  Fayzabad  37.116638  70.580022
# 1  2000-01-15       Balkh  Mazar-e-Sharif     Mazar  36.725116  67.109571
# 2  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 3  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 4  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
#
#              category                                      commodity unit  \
# 0            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 1            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 2  cereals and tubers                                          Bread   KG
# 3  cereals and tubers                                          Wheat   KG
# 4  cereals and tubers                                    Wheat flour   KG
#
#   priceflag pricetype currency      price   usdprice  iso
# 0    actual    Retail      AFN  150000.00  3205.7378  AFG
# 1    actual    Retail      AFN  100000.00  2137.1586  AFG
# 2    actual    Retail      AFN      15.63     0.3340  AFG
# 3    actual    Retail      AFN       9.13     0.1951  AFG
# 4    actual    Retail      AFN      10.06     0.2150  AFG

# %%
df_food.index # index
# Out:
# RangeIndex(start=0, stop=3542751, step=1)

# %% [markdown]
# <a id='wrangling'></a>
# ### Data wrangling
# [Back to top](#top)

# %%
# Analyzing priceflag and pricetype columns

df_food[['priceflag','pricetype']].value_counts()
# Out:
# priceflag         pricetype
# actual            Retail       1939444
# forecast          Retail        754906
# aggregate         Retail        550001
# actual            Wholesale     158295
# aggregate         Wholesale      69322
# forecast          Wholesale      61364
# actual,aggregate  Retail          7813
#                   Wholesale        801
# actual            Farm Gate        437
#                   Producer         248
# forecast          Producer          72
#                   Farm Gate         48
# dtype: int64

# %%
# I'm only interested in actual and aggregated retail prices. All other categories will be removed 

df_food=df_food.drop(df_food[df_food['priceflag']=='forecast'].index)

# %%
df_food[['priceflag','pricetype']].value_counts()
# Out:
# priceflag         pricetype
# actual            Retail       1939444
# aggregate         Retail        550001
# actual            Wholesale     158295
# aggregate         Wholesale      69322
# actual,aggregate  Retail          7813
#                   Wholesale        801
# actual            Farm Gate        437
#                   Producer         248
# dtype: int64

# %%
df_food['iso'].nunique()
# Out:
# 99

# %%
df_food.shape
# Out:
# (2726361, 15)

# %%
# Analyzing the category and comodity columns content to figure out what records could be removed

pivot_table=pd.pivot_table(df_food, values='date', index=['commodity'], columns=['category'], aggfunc='count')

pivot_table # the dataframe contains 730 commodities and 8 categories
# Out:
# category                cereals and tubers  meat, fish and eggs  \
# commodity
# Alcohol (spray)                        NaN                  NaN
# Anchovies                              NaN               1640.0
# Antibacterial wipes                    NaN                  NaN
# Antibiotics (imported)                 NaN                  NaN
# Antibiotics (local)                    NaN                  NaN
# ...                                    ...                  ...
# Yam (yellow)                         157.0                  NaN
# Yeast                                  NaN                  NaN
# Yogurt                                 NaN                  NaN
# Young fern                             NaN                  NaN
# Zucchini                               NaN                  NaN
#
# category                milk and dairy  miscellaneous food  non-food  \
# commodity
# Alcohol (spray)                    NaN                 NaN    2470.0
# Anchovies                          NaN                 NaN       NaN
# Antibacterial wipes                NaN                 NaN     195.0
# Antibiotics (imported)             NaN                 NaN    1350.0
# Antibiotics (local)                NaN                 NaN    1350.0
# ...                                ...                 ...       ...
# Yam (yellow)                       NaN                 NaN       NaN
# Yeast                              NaN               131.0       NaN
# Yogurt                          6364.0                 NaN       NaN
# Young fern                         NaN                 NaN       NaN
# Zucchini                           NaN                 NaN       NaN
#
# category                oil and fats  pulses and nuts  vegetables and fruits
# commodity
# Alcohol (spray)                  NaN              NaN                    NaN
# Anchovies                        NaN              NaN                    NaN
# Antibacterial wipes              NaN              NaN                    NaN
# Antibiotics (imported)           NaN              NaN                    NaN
# Antibiotics (local)              NaN              NaN                    NaN
# ...                              ...              ...                    ...
# Yam (yellow)                     NaN              NaN                    NaN
# Yeast                            NaN              NaN                    NaN
# Yogurt                           NaN              NaN                    NaN
# Young fern                       NaN              NaN                   35.0
# Zucchini                         NaN              NaN                 1219.0
#
# [730 rows x 8 columns]

# %%
# Analyzing non-food category

df_food['commodity'][df_food['category']=='non-food'].value_counts()
# Out:
# Fuel (diesel)                  35670
# Fuel (petrol-gasoline)         24929
# Fuel (gas)                     12573
# Wage (non-qualified labour)     9948
# Exchange rate (unofficial)      7977
#                                ...
# Pole                              87
# Straw                             63
# Transport (public, moto)          42
# Feed (wheat bran)                 16
# Cotton                            10
# Name: commodity, Length: 85, dtype: int64

# %%
df_just_food=df_food.copy()
df_just_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2726361 entries, 0 to 3541113
# Data columns (total 15 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   date       object
#  1   admin1     object
#  2   admin2     object
#  3   market     object
#  4   latitude   float64
#  5   longitude  float64
#  6   category   object
#  7   commodity  object
#  8   unit       object
#  9   priceflag  object
#  10  pricetype  object
#  11  currency   object
#  12  price      float64
#  13  usdprice   float64
#  14  iso        object
# dtypes: float64(4), object(11)
# memory usage: 332.8+ MB

# %%
# Analyzing the comodity and unit columns 

pd.pivot_table(df_just_food, values='date', index=['commodity'], columns=['unit'], aggfunc='count')
# Out:
# unit                    0.13 KG  0.5 KG  0.8 KG  1 GB  1 piece  1 sachet  \
# commodity
# Alcohol (spray)             NaN     NaN     NaN   NaN      NaN       NaN
# Anchovies                   NaN     NaN     NaN   NaN      NaN       NaN
# Antibacterial wipes         NaN     NaN     NaN   NaN      NaN       NaN
# Antibiotics (imported)      NaN     NaN     NaN   NaN      NaN       NaN
# Antibiotics (local)         NaN     NaN     NaN   NaN      NaN       NaN
# ...                         ...     ...     ...   ...      ...       ...
# Yam (yellow)                NaN     NaN     NaN   NaN      NaN       NaN
# Yeast                       NaN     NaN     NaN   NaN      NaN       NaN
# Yogurt                      NaN     NaN     NaN   NaN      NaN       NaN
# Young fern                  NaN     NaN     NaN   NaN      NaN       NaN
# Zucchini                    NaN     NaN     NaN   NaN      NaN       NaN
#
# unit                    1 ticket  1.1 KG  1.2 KG  1.3 KG  ...  Month  Package  \
# commodity                                                 ...
# Alcohol (spray)              NaN     NaN     NaN     NaN  ...    NaN      NaN
# Anchovies                    NaN     NaN     NaN     NaN  ...    NaN      NaN
# Antibacterial wipes          NaN     NaN     NaN     NaN  ...    NaN      NaN
# Antibiotics (imported)       NaN     NaN     NaN     NaN  ...    NaN      NaN
# Antibiotics (local)          NaN     NaN     NaN     NaN  ...    NaN      NaN
# ...                          ...     ...     ...     ...  ...    ...      ...
# Yam (yellow)                 NaN     NaN     NaN     NaN  ...    NaN      NaN
# Yeast                        NaN     NaN     NaN     NaN  ...    NaN      NaN
# Yogurt                       NaN     NaN     NaN     NaN  ...    NaN      NaN
# Young fern                   NaN     NaN     NaN     NaN  ...    NaN      NaN
# Zucchini                     NaN     NaN     NaN     NaN  ...    NaN      NaN
#
# unit                    Packet  Pair  Pile  Pound  Sack  USD/LCU  Unit  kWh
# commodity
# Alcohol (spray)            NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Anchovies                  NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Antibacterial wipes      195.0   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Antibiotics (imported)     NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Antibiotics (local)        NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# ...                        ...   ...   ...    ...   ...      ...   ...  ...
# Yam (yellow)               NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Yeast                      NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Yogurt                     NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Young fern                 NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
# Zucchini                   NaN   NaN   NaN    NaN   NaN      NaN   NaN  NaN
#
# [730 rows x 156 columns]

# %%
# Analyzing the unit column

df_just_food['unit'].value_counts() # there are 131 different units
# Out:
# KG         1988591
# L           197180
# 100 KG       62897
# Unit         54099
# Head         25092
#             ...
# 0.13 KG         17
# 450 ML          17
# 240 G           17
# 450 G           17
# 4.5 KG           2
# Name: unit, Length: 156, dtype: int64

# %% [markdown]
# To be able to compare the price of vrious products I need to unify the units according to the following plan:
# 1. Split unit column into two: measure and measure unit
# 2. Calculate the price for KG, price for L and price for single unit of each product

# %%
# Splitting the unit column

df_just_food[['measure','measure_unit']]=df_just_food['unit'].str.split(' ', expand=True)

# %%
df_just_food.head()
# Out:
#          date      admin1          admin2    market   latitude  longitude  \
# 0  2000-01-15  Badakhshan       Faiz Abad  Fayzabad  37.116638  70.580022
# 1  2000-01-15       Balkh  Mazar-e-Sharif     Mazar  36.725116  67.109571
# 2  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 3  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 4  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
#
#              category                                      commodity unit  \
# 0            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 1            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 2  cereals and tubers                                          Bread   KG
# 3  cereals and tubers                                          Wheat   KG
# 4  cereals and tubers                                    Wheat flour   KG
#
#   priceflag pricetype currency      price   usdprice  iso measure measure_unit
# 0    actual    Retail      AFN  150000.00  3205.7378  AFG     Day         None
# 1    actual    Retail      AFN  100000.00  2137.1586  AFG     Day         None
# 2    actual    Retail      AFN      15.63     0.3340  AFG      KG         None
# 3    actual    Retail      AFN       9.13     0.1951  AFG      KG         None
# 4    actual    Retail      AFN      10.06     0.2150  AFG      KG         None

# %%
# Setting up measure value to 1 if measure unit is None

df_just_food.loc[df_just_food['measure_unit'].isnull(), 'measure']='1'

# %%
df_just_food.head()
# Out:
#          date      admin1          admin2    market   latitude  longitude  \
# 0  2000-01-15  Badakhshan       Faiz Abad  Fayzabad  37.116638  70.580022
# 1  2000-01-15       Balkh  Mazar-e-Sharif     Mazar  36.725116  67.109571
# 2  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 3  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 4  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
#
#              category                                      commodity unit  \
# 0            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 1            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 2  cereals and tubers                                          Bread   KG
# 3  cereals and tubers                                          Wheat   KG
# 4  cereals and tubers                                    Wheat flour   KG
#
#   priceflag pricetype currency      price   usdprice  iso measure measure_unit
# 0    actual    Retail      AFN  150000.00  3205.7378  AFG       1         None
# 1    actual    Retail      AFN  100000.00  2137.1586  AFG       1         None
# 2    actual    Retail      AFN      15.63     0.3340  AFG       1         None
# 3    actual    Retail      AFN       9.13     0.1951  AFG       1         None
# 4    actual    Retail      AFN      10.06     0.2150  AFG       1         None

# %%
df_just_food['measure'].value_counts()
# Out:
# 1       2381617
# 100       74709
# 10        25311
# 50        21231
# 90        14836
#          ...
# 450          34
# 240          17
# 180          17
# 0.13         17
# 4.5           2
# Name: measure, Length: 94, dtype: int64

# %%
# Imputing missing measure_unit values with the values fron unit column

df_just_food.loc[df_just_food['measure_unit'].isnull(), 'measure_unit']=df_just_food['unit']

# %%
df_just_food.head()
# Out:
#          date      admin1          admin2    market   latitude  longitude  \
# 0  2000-01-15  Badakhshan       Faiz Abad  Fayzabad  37.116638  70.580022
# 1  2000-01-15       Balkh  Mazar-e-Sharif     Mazar  36.725116  67.109571
# 2  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 3  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 4  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
#
#              category                                      commodity unit  \
# 0            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 1            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 2  cereals and tubers                                          Bread   KG
# 3  cereals and tubers                                          Wheat   KG
# 4  cereals and tubers                                    Wheat flour   KG
#
#   priceflag pricetype currency      price   usdprice  iso measure measure_unit
# 0    actual    Retail      AFN  150000.00  3205.7378  AFG       1          Day
# 1    actual    Retail      AFN  100000.00  2137.1586  AFG       1          Day
# 2    actual    Retail      AFN      15.63     0.3340  AFG       1           KG
# 3    actual    Retail      AFN       9.13     0.1951  AFG       1           KG
# 4    actual    Retail      AFN      10.06     0.2150  AFG       1           KG

# %%
df_just_food['measure_unit'].value_counts()
# Out:
# KG           2190364
# L             210455
# G              62431
# Unit           54099
# pcs            30011
# Head           25092
# Day            24104
# ML             20446
# USD/LCU        15660
# Pound          11377
# Packet          9001
# Marmite         8379
# tablets         6750
# Gallon          6208
# Pounds          5853
# MT              4256
# Loaf            3875
# piece           3635
# Libra           3591
# Bar             3557
# Bunch           2852
# Pair            2606
# GB              2415
# Course          2159
# Tubers          2051
# Sack            1807
# Dozen           1353
# Cylinder        1263
# ticket          1260
# sachet          1245
# Box             1194
# Bundle          1178
# LCU/3.5kg       1142
# meter           1079
# Brush           1026
# ml               738
# Cuartilla        586
# Dozens           337
# Package          269
# kWh              262
# Pile             244
# Month             88
# Heap              63
# Name: measure_unit, dtype: int64

# %%
df_just_food['measure'].value_counts()
# Out:
# 1       2381617
# 100       74709
# 10        25311
# 50        21231
# 90        14836
#          ...
# 450          34
# 240          17
# 180          17
# 0.13         17
# 4.5           2
# Name: measure, Length: 94, dtype: int64

# %%
# Checking what'Day' measure means

df_just_food.loc[df_just_food['measure_unit']=='Day']
# Out:
#                date      admin1          admin2             market   latitude  \
# 0        2000-01-15  Badakhshan       Faiz Abad           Fayzabad  37.116638
# 1        2000-01-15       Balkh  Mazar-e-Sharif              Mazar  36.725116
# 5        2000-01-15       Hirat           Hirat              Hirat  34.346944
# 9        2000-01-15       Kabul           Kabul              Kabul  34.516667
# 13       2000-01-15    Kandahar        Kandahar           Kandahar  31.612500
# ...             ...         ...             ...                ...        ...
# 3448957  2023-07-15     Shabwah          Bayhan         Attaq Town  14.801087
# 3448975  2023-07-15     Socotra         Hidaybu  Soqatra (Hudaibo)  12.650000
# 3448976  2023-07-15     Socotra         Hidaybu  Soqatra (Hudaibo)  12.650000
# 3448992  2023-07-15       Taizz      Al Qahirah          Taiz City  13.580000
# 3448993  2023-07-15       Taizz      Al Qahirah          Taiz City  13.580000
#
#          longitude  category                                      commodity  \
# 0        70.580022  non-food  Wage (non-qualified labour, non-agricultural)
# 1        67.109571  non-food  Wage (non-qualified labour, non-agricultural)
# 5        62.198333  non-food  Wage (non-qualified labour, non-agricultural)
# 9        69.183333  non-food  Wage (non-qualified labour, non-agricultural)
# 13       65.709444  non-food  Wage (non-qualified labour, non-agricultural)
# ...            ...       ...                                            ...
# 3448957  45.719959  non-food                        Wage (qualified labour)
# 3448975  54.033333  non-food                    Wage (non-qualified labour)
# 3448976  54.033333  non-food                        Wage (qualified labour)
# 3448992  44.020000  non-food                    Wage (non-qualified labour)
# 3448993  44.020000  non-food                        Wage (qualified labour)
#
#         unit priceflag pricetype currency     price   usdprice  iso measure  \
# 0        Day    actual    Retail      AFN  150000.0  3205.7378  AFG       1
# 1        Day    actual    Retail      AFN  100000.0  2137.1586  AFG       1
# 5        Day    actual    Retail      AFN   60000.0  1282.2951  AFG       1
# 9        Day    actual    Retail      AFN   55000.0  1175.4372  AFG       1
# 13       Day    actual    Retail      AFN   75000.0  1602.8689  AFG       1
# ...      ...       ...       ...      ...       ...        ...  ...     ...
# 3448957  Day    actual    Retail      YER   15000.0    10.7603  YEM       1
# 3448975  Day    actual    Retail      YER   15000.0    10.7603  YEM       1
# 3448976  Day    actual    Retail      YER   20000.0    14.3470  YEM       1
# 3448992  Day    actual    Retail      YER    8000.0     5.7388  YEM       1
# 3448993  Day    actual    Retail      YER   15000.0    10.7603  YEM       1
#
#         measure_unit
# 0                Day
# 1                Day
# 5                Day
# 9                Day
# 13               Day
# ...              ...
# 3448957          Day
# 3448975          Day
# 3448976          Day
# 3448992          Day
# 3448993          Day
#
# [24104 rows x 17 columns]

# %%
# Analyzing comodity values that include details in parentheses 

df_comodity=df_just_food.loc[df_just_food['commodity'].str.endswith(')')]

# %%
df_comodity 

#I will remove information in prentheses to be able to find an average price for the same product for a certain country and date
# Out:
#                date              admin1          admin2              market  \
# 0        2000-01-15          Badakhshan       Faiz Abad            Fayzabad
# 1        2000-01-15               Balkh  Mazar-e-Sharif               Mazar
# 5        2000-01-15               Hirat           Hirat               Hirat
# 9        2000-01-15               Kabul           Kabul               Kabul
# 13       2000-01-15            Kandahar        Kandahar            Kandahar
# ...             ...                 ...             ...                 ...
# 3541102  2023-01-15    Mashonaland West    Kariba Urban        Mahombekombe
# 3541103  2023-01-15    Mashonaland West    Kariba Urban        Mahombekombe
# 3541106  2023-01-15  Matabeleland North           Nkayi  Nkayi Growth Point
# 3541112  2023-01-15  Matabeleland North           Nkayi  Nkayi Growth Point
# 3541113  2023-01-15  Matabeleland North           Nkayi  Nkayi Growth Point
#
#           latitude  longitude             category  \
# 0        37.116638  70.580022             non-food
# 1        36.725116  67.109571             non-food
# 5        34.346944  62.198333             non-food
# 9        34.516667  69.183333             non-food
# 13       31.612500  65.709444             non-food
# ...            ...        ...                  ...
# 3541102 -16.525861  28.778411         oil and fats
# 3541103 -16.525861  28.778411      pulses and nuts
# 3541106 -18.999158  28.898316  meat, fish and eggs
# 3541112 -18.999158  28.898316         oil and fats
# 3541113 -18.999158  28.898316      pulses and nuts
#
#                                              commodity unit  priceflag  \
# 0        Wage (non-qualified labour, non-agricultural)  Day     actual
# 1        Wage (non-qualified labour, non-agricultural)  Day     actual
# 5        Wage (non-qualified labour, non-agricultural)  Day     actual
# 9        Wage (non-qualified labour, non-agricultural)  Day     actual
# 13       Wage (non-qualified labour, non-agricultural)  Day     actual
# ...                                                ...  ...        ...
# 3541102                                Oil (vegetable)    L  aggregate
# 3541103                                  Beans (sugar)   KG  aggregate
# 3541106                                 Fish (kapenta)   KG  aggregate
# 3541112                                Oil (vegetable)    L  aggregate
# 3541113                                  Beans (sugar)   KG  aggregate
#
#         pricetype currency      price   usdprice  iso measure measure_unit
# 0          Retail      AFN  150000.00  3205.7378  AFG       1          Day
# 1          Retail      AFN  100000.00  2137.1586  AFG       1          Day
# 5          Retail      AFN   60000.00  1282.2951  AFG       1          Day
# 9          Retail      AFN   55000.00  1175.4372  AFG       1          Day
# 13         Retail      AFN   75000.00  1602.8689  AFG       1          Day
# ...           ...      ...        ...        ...  ...     ...          ...
# 3541102    Retail      ZWL    2018.75     2.7643  ZWE       1            L
# 3541103    Retail      ZWL    1545.00     2.1156  ZWE       1           KG
# 3541106    Retail      ZWL    9636.00    13.1947  ZWE       1           KG
# 3541112    Retail      ZWL    2000.00     2.7386  ZWE       1            L
# 3541113    Retail      ZWL    1600.00     2.1909  ZWE       1           KG
#
# [1610545 rows x 17 columns]

# %%
# Analyzing powdered products that can or can't be analyzed as the same product

df_powder=df_just_food.loc[df_just_food['commodity'].str.contains(pat='powder')]

# %%
df_powder[['commodity','measure_unit']].value_counts()

# Powdered milk will be analyzed as a different product - Powdered Milk
# Out:
# commodity                      measure_unit
# Milk (powder)                  KG              5047
#                                G               4252
#                                Unit            1522
# Cocoa (powder)                 G               1120
# Milk (powder, infant formula)  KG               429
# Cocoa (powder)                 KG               287
# Milk (powder)                  Pounds           156
#                                Pound             84
# dtype: int64

# %%
# Changing Milk (powder) to Powdered Milk

df_just_food.loc[df_just_food['commodity']=='Milk (powder)', 'commodity'] = 'Powdered milk'
df_just_food.loc[df_just_food['commodity']=='Milk (powder, infant formula)', 'commodity'] = 'Powdered milk'

# %%
df_milk=df_just_food.loc[df_just_food['commodity'].str.contains(pat='Milk')]

# %%
df_milk[['commodity','measure_unit']].value_counts()
# Out:
# commodity                measure_unit
# Milk (pasteurized)       L               11064
# Milk                     L                9307
# Milk (non-pasteurized)   L                4654
# Milk                     KG               2484
# Milk (condensed)         ML               2071
# Milk (cow, fresh)        L                1563
# Milk (camel)             L                1248
# Milk                     G                 882
# Milk (fresh)             L                 828
# Milk (pasteurized)       KG                610
# Milk (UHT)               ML                356
# Milk (cow, pasteurized)  ML                178
# Milk (condensed)         G                 158
# Milk (pasteurized)       ML                100
# Milk (camel, fresh)      L                  78
# Milk (pasteurized)       G                  68
# Milk (cow, pasteurized)  L                  21
# dtype: int64

# %%
# Splitting commodity column to separate the product name from the notes in the parentheses

df_just_food[['product_name','product_notes']]=df_just_food['commodity'].str.split('(', expand=True)

# %%
df_just_food.head()
# Out:
#          date      admin1          admin2    market   latitude  longitude  \
# 0  2000-01-15  Badakhshan       Faiz Abad  Fayzabad  37.116638  70.580022
# 1  2000-01-15       Balkh  Mazar-e-Sharif     Mazar  36.725116  67.109571
# 2  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 3  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 4  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
#
#              category                                      commodity unit  \
# 0            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 1            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 2  cereals and tubers                                          Bread   KG
# 3  cereals and tubers                                          Wheat   KG
# 4  cereals and tubers                                    Wheat flour   KG
#
#   priceflag pricetype currency      price   usdprice  iso measure  \
# 0    actual    Retail      AFN  150000.00  3205.7378  AFG       1
# 1    actual    Retail      AFN  100000.00  2137.1586  AFG       1
# 2    actual    Retail      AFN      15.63     0.3340  AFG       1
# 3    actual    Retail      AFN       9.13     0.1951  AFG       1
# 4    actual    Retail      AFN      10.06     0.2150  AFG       1
#
#   measure_unit product_name                            product_notes
# 0          Day        Wage   non-qualified labour, non-agricultural)
# 1          Day        Wage   non-qualified labour, non-agricultural)
# 2           KG        Bread                                     None
# 3           KG        Wheat                                     None
# 4           KG  Wheat flour                                     None

# %%
df_just_food['product_name'].value_counts() # There are 261 food and non-food commodities in the dataframe
# Out:
# Rice               235299
# Meat               189651
# Oil                145195
# Beans              104911
# Fuel                94612
#                     ...
# Meat                   15
# Cotton                 10
# Corn Soy Blend          5
# Butter                  4
# Kocho                   1
# Name: product_name, Length: 261, dtype: int64

# %%
# I realize that the same product can be quite different in various parts of the world.
# But this analysys will focus on types of products in general and ignore the differences.

df_just_food['product_notes'].value_counts()
# Out:
# white)             117928
# imported)           78495
# local)              78252
# red)                50883
# vegetable)          45218
#                     ...
# basmati)                2
# Turkey)                 2
# haricot, white)         2
# cow milk)               2
# haricot, red)           1
# Name: product_notes, Length: 430, dtype: int64

# %%
df_just_food['product_name'].iloc[0]
# Out:
# 'Wage '

# %%
# Trimming an extra space in product_name columns

df_just_food['product_name']=df_just_food['product_name'].apply(lambda x: x.strip())

# %%
df_just_food['product_name'].iloc[0]
# Out:
# 'Wage'

# %%
# Removing unnecessary columns

df_food_removed=df_just_food.drop(columns=['admin1','admin2','priceflag','product_notes'])

# %%
df_food_removed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2726361 entries, 0 to 3541113
# Data columns (total 15 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   market        object
#  2   latitude      float64
#  3   longitude     float64
#  4   category      object
#  5   commodity     object
#  6   unit          object
#  7   pricetype     object
#  8   currency      object
#  9   price         float64
#  10  usdprice      float64
#  11  iso           object
#  12  measure       object
#  13  measure_unit  object
#  14  product_name  object
# dtypes: float64(4), object(11)
# memory usage: 397.3+ MB

# %%
# Analyzing non-numerical measure values

df_food_removed.loc[df_food_removed['measure_unit']=='meter']
# Out:
#                date            market   latitude  longitude  category  \
# 1523058  2022-04-15     Tehran Market  35.720000  51.400000  non-food
# 1523061  2022-04-15     Tehran Market  35.720000  51.400000  non-food
# 1523092  2022-05-15     Tehran Market  35.720000  51.400000  non-food
# 1523095  2022-05-15     Tehran Market  35.720000  51.400000  non-food
# 1523126  2022-06-15     Tehran Market  35.720000  51.400000  non-food
# ...             ...               ...        ...        ...       ...
# 3216009  2022-03-15             Izmir  38.423698  27.142799  non-food
# 3216052  2022-04-15  National Average        NaN        NaN  non-food
# 3216092  2022-04-15            Ankara  39.933399  32.859699  non-food
# 3216132  2022-04-15          Istanbul  41.012639  28.966742  non-food
# 3216172  2022-04-15             Izmir  38.423698  27.142799  non-food
#
#           commodity         unit pricetype currency     price  usdprice  iso  \
# 1523058  Fuel (gas)  Cubic meter    Retail      IRR    966.00    0.0230  IRN
# 1523061       Water  Cubic meter    Retail      IRR  11640.00    0.2771  IRN
# 1523092  Fuel (gas)  Cubic meter    Retail      IRR    966.00    0.0230  IRN
# 1523095       Water  Cubic meter    Retail      IRR  11640.00    0.2771  IRN
# 1523126  Fuel (gas)  Cubic meter    Retail      IRR    966.00    0.0230  IRN
# ...             ...          ...       ...      ...       ...       ...  ...
# 3216009       Water  Cubic meter    Retail      TRY     10.84    0.7335  TUR
# 3216052       Water  Cubic meter    Retail      TRY      8.59    0.5875  TUR
# 3216092       Water  Cubic meter    Retail      TRY     10.25    0.7013  TUR
# 3216132       Water  Cubic meter    Retail      TRY      9.47    0.6477  TUR
# 3216172       Water  Cubic meter    Retail      TRY     11.57    0.7912  TUR
#
#         measure measure_unit product_name
# 1523058   Cubic        meter         Fuel
# 1523061   Cubic        meter        Water
# 1523092   Cubic        meter         Fuel
# 1523095   Cubic        meter        Water
# 1523126   Cubic        meter         Fuel
# ...         ...          ...          ...
# 3216009   Cubic        meter        Water
# 3216052   Cubic        meter        Water
# 3216092   Cubic        meter        Water
# 3216132   Cubic        meter        Water
# 3216172   Cubic        meter        Water
#
# [1079 rows x 15 columns]

# %%
# Changing measure unit to cubic measure

df_food_removed.loc[(df_food_removed['measure']=='Cubic')&(df_food_removed['measure_unit']=='meter'), 'measure_unit']='Cubic meter'

# %%
df_food_removed.loc[(df_food_removed['measure']=='Cubic')&(df_food_removed['measure_unit']!='Cubic meter')]
# Out:
# Empty DataFrame
# Columns: [date, market, latitude, longitude, category, commodity, unit, pricetype, currency, price, usdprice, iso, measure, measure_unit, product_name]
# Index: []

# %%
df_food_removed.loc[df_food_removed['measure']=='Cubic', 'measure']=1

# %%
# Changing datatype to float

df_food_removed['measure']=df_food_removed['measure'].astype(float)
df_food_removed['measure'].dtype
# Out:
# dtype('float64')

# %%
# Changing date from string to date format

df_food_removed['date']=pd.to_datetime(df_food_removed['date'])

# %%
df_food_removed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2726361 entries, 0 to 3541113
# Data columns (total 15 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          datetime64[ns]
#  1   market        object
#  2   latitude      float64
#  3   longitude     float64
#  4   category      object
#  5   commodity     object
#  6   unit          object
#  7   pricetype     object
#  8   currency      object
#  9   price         float64
#  10  usdprice      float64
#  11  iso           object
#  12  measure       float64
#  13  measure_unit  object
#  14  product_name  object
# dtypes: datetime64[ns](1), float64(5), object(9)
# memory usage: 397.3+ MB

# %% [markdown]
# <a id='cleaning'></a>
# ### Data cleaning
# [Back to top](#top)

# %% [markdown]
# Changing inconsistent measure units as follows:
# G = 0.001 KG
# ML, ml = 0.001 L
# Gallon = 3.8 L
# Cuartilla = 13.9 L
# Pound/Pounds/Libra = 0.45 KG
# MT = 1000 KG
# LCU/3.5kg = 3.5 KG
# The rest of the units = Unit

# %%
df_food_removed.loc[df_food_removed['measure_unit']=='LCU/3.5kg']
# Out:
#               date      market  latitude  longitude  category  \
# 2816729 2018-08-15  Konyokonyo  4.845972  31.601203  non-food
# 2816758 2018-08-15         Bor  6.210000  31.570000  non-food
# 2816837 2018-08-15         Jau  7.701110  27.989719  non-food
# 2816866 2018-09-15  Konyokonyo  4.845972  31.601203  non-food
# 2816896 2018-09-15         Bor  6.210000  31.570000  non-food
# ...            ...         ...       ...        ...       ...
# 2845984 2023-08-15         Jau  7.701110  27.989719  non-food
# 2846011 2023-08-15    Makpandu  4.739905  28.679766  non-food
# 2846012 2023-08-15    Makpandu  4.739905  28.679766  non-food
# 2846043 2023-08-15      Yambio  4.550833  28.416668  non-food
# 2846044 2023-08-15      Yambio  4.550833  28.416668  non-food
#
#                       commodity       unit pricetype currency  price  \
# 2816729  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP   70.0
# 2816758  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP   85.0
# 2816837  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP  100.0
# 2816866  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP  100.0
# 2816896  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP  100.0
# ...                         ...        ...       ...      ...    ...
# 2845984  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP  700.0
# 2846011    Milling cost (maize)  LCU/3.5kg    Retail      SSP  900.0
# 2846012  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP  900.0
# 2846043    Milling cost (maize)  LCU/3.5kg    Retail      SSP  400.0
# 2846044  Milling cost (sorghum)  LCU/3.5kg    Retail      SSP  400.0
#
#          usdprice  iso  measure measure_unit  product_name
# 2816729    0.4809  SSD      1.0    LCU/3.5kg  Milling cost
# 2816758    0.5840  SSD      1.0    LCU/3.5kg  Milling cost
# 2816837    0.6870  SSD      1.0    LCU/3.5kg  Milling cost
# 2816866    0.6715  SSD      1.0    LCU/3.5kg  Milling cost
# 2816896    0.6715  SSD      1.0    LCU/3.5kg  Milling cost
# ...           ...  ...      ...          ...           ...
# 2845984    0.7011  SSD      1.0    LCU/3.5kg  Milling cost
# 2846011    0.9015  SSD      1.0    LCU/3.5kg  Milling cost
# 2846012    0.9015  SSD      1.0    LCU/3.5kg  Milling cost
# 2846043    0.4007  SSD      1.0    LCU/3.5kg  Milling cost
# 2846044    0.4007  SSD      1.0    LCU/3.5kg  Milling cost
#
# [1142 rows x 15 columns]

# %%
# Changing measures to KG, L, and Units

df_food_removed.loc[df_food_removed['measure_unit']=='G', 'measure']=df_food_removed['measure']*0.001
df_food_removed.loc[df_food_removed['measure_unit'].isin(['Pound','Pounds','Libra']), 'measure']=df_food_removed['measure']*0.45
df_food_removed.loc[df_food_removed['measure_unit']=='MT', 'measure']=df_food_removed['measure']*1000
df_food_removed.loc[df_food_removed['measure_unit'].isin(['ML','ml']), 'measure']=df_food_removed['measure']*0.001
df_food_removed.loc[df_food_removed['measure_unit']=='Gallon', 'measure']=df_food_removed['measure']*3.8
df_food_removed.loc[df_food_removed['measure_unit']=='Cuartilla', 'measure']=df_food_removed['measure']*13.9
df_food_removed.loc[df_food_removed['measure_unit']=='LCU/3.5kg', 'measure']=df_food_removed['measure']*3.5

# %%
df_food_removed['measure'].value_counts()
# Out:
# 1.00      2355536
# 100.00      65063
# 10.00       25311
# 50.00       18298
# 0.45        15002
#            ...
# 360.00         52
# 0.24           17
# 0.18           17
# 0.13           17
# 4.50            2
# Name: measure, Length: 99, dtype: int64

# %%
#Checking the result

df_food_removed.loc[df_food_removed['measure_unit']=='ml']
# Out:
#               date         market   latitude  longitude  category   commodity  \
# 1539726 2020-03-15          Anbar  33.416312  43.302097  non-food  Toothpaste
# 1539736 2020-03-15        Babylon  32.483182  44.437380  non-food  Toothpaste
# 1539746 2020-03-15        Baghdad  33.338611  44.393889  non-food  Toothpaste
# 1539756 2020-03-15         Basrah  30.534884  47.788846  non-food  Toothpaste
# 1539766 2020-03-15          Dohuk  36.869498  42.993982  non-food  Toothpaste
# ...            ...            ...        ...        ...       ...         ...
# 1564924 2023-07-15       Qadisiya  31.987723  44.930177  non-food  Toothpaste
# 1564960 2023-07-15  Salah al-deen  34.597186  43.685675  non-food  Toothpaste
# 1564996 2023-07-15   Sulaimaniyah  35.561127  45.437487  non-food  Toothpaste
# 1565032 2023-07-15        Thi-Qar  31.048263  46.271753  non-food  Toothpaste
# 1565068 2023-07-15          Wasit  32.510220  45.813560  non-food  Toothpaste
#
#            unit pricetype currency    price  usdprice  iso  measure  \
# 1539726  150 ml    Retail      IQD  2000.00    1.6920  IRQ     0.15
# 1539736  150 ml    Retail      IQD  1500.00    1.2690  IRQ     0.15
# 1539746  150 ml    Retail      IQD  3000.00    2.5381  IRQ     0.15
# 1539756  150 ml    Retail      IQD  4000.00    3.3841  IRQ     0.15
# 1539766  150 ml    Retail      IQD  3000.00    2.5381  IRQ     0.15
# ...         ...       ...      ...      ...       ...  ...      ...
# 1564924  150 ml    Retail      IQD  3000.00    2.3077  IRQ     0.15
# 1564960  150 ml    Retail      IQD  5000.00    3.8462  IRQ     0.15
# 1564996  150 ml    Retail      IQD  1883.33    1.4487  IRQ     0.15
# 1565032  150 ml    Retail      IQD  4000.00    3.0769  IRQ     0.15
# 1565068  150 ml    Retail      IQD  3000.00    2.3077  IRQ     0.15
#
#         measure_unit product_name
# 1539726           ml   Toothpaste
# 1539736           ml   Toothpaste
# 1539746           ml   Toothpaste
# 1539756           ml   Toothpaste
# 1539766           ml   Toothpaste
# ...              ...          ...
# 1564924           ml   Toothpaste
# 1564960           ml   Toothpaste
# 1564996           ml   Toothpaste
# 1565032           ml   Toothpaste
# 1565068           ml   Toothpaste
#
# [738 rows x 15 columns]

# %%
df_food_removed.loc[df_food_removed['measure_unit']=='GB']
# Out:
#               date        market   latitude  longitude  category  \
# 2933966 2020-06-15    Al-Hasakeh  36.481689  40.756191  non-food
# 2934012 2020-06-15     Quamishli  37.052361  41.241371  non-food
# 2934054 2020-06-15         A'zaz  36.585899  37.045650  non-food
# 2934094 2020-06-15         Afrin  36.452709  36.816860  non-food
# 2934136 2020-06-15     Der Hafir  36.156387  37.703697  non-food
# ...            ...           ...        ...        ...       ...
# 3042159 2023-04-15       Qudsiya  33.549999  36.216671  non-food
# 3042205 2023-04-15         Saqba  33.516521  36.379803  non-food
# 3042252 2023-04-15  Rural Safita  34.875881  36.257259  non-food
# 3042298 2023-04-15   Sheikh Badr  34.990974  36.079144  non-food
# 3042346 2023-04-15       Tartous  34.890017  35.889063  non-food
#
#                commodity  unit pricetype currency   price  usdprice  iso  \
# 2933966  Internet bundle  1 GB    Retail      SYP  2750.0    6.3001  SYR
# 2934012  Internet bundle  1 GB    Retail      SYP  2750.0    6.3001  SYR
# 2934054  Internet bundle  1 GB    Retail      SYP  2000.0    4.5819  SYR
# 2934094  Internet bundle  1 GB    Retail      SYP  2000.0    4.5819  SYR
# 2934136  Internet bundle  1 GB    Retail      SYP  2750.0    6.3001  SYR
# ...                  ...   ...       ...      ...     ...       ...  ...
# 3042159  Internet bundle  1 GB    Retail      SYP  7800.0   17.8694  SYR
# 3042205  Internet bundle  1 GB    Retail      SYP  7800.0   17.8694  SYR
# 3042252  Internet bundle  1 GB    Retail      SYP  7800.0   17.8694  SYR
# 3042298  Internet bundle  1 GB    Retail      SYP  7800.0   17.8694  SYR
# 3042346  Internet bundle  1 GB    Retail      SYP  7800.0   17.8694  SYR
#
#          measure measure_unit     product_name
# 2933966      1.0           GB  Internet bundle
# 2934012      1.0           GB  Internet bundle
# 2934054      1.0           GB  Internet bundle
# 2934094      1.0           GB  Internet bundle
# 2934136      1.0           GB  Internet bundle
# ...          ...          ...              ...
# 3042159      1.0           GB  Internet bundle
# 3042205      1.0           GB  Internet bundle
# 3042252      1.0           GB  Internet bundle
# 3042298      1.0           GB  Internet bundle
# 3042346      1.0           GB  Internet bundle
#
# [2415 rows x 15 columns]

# %%
# Changing measure units to KG, L or Unit

to_kg=['G','Pound','Pounds','Libra','MT','LCU/3.5kg']
to_l=['ML','Gallon','Cuartilla','ml']

# %%
df_food_removed['measure_unit']=df_food_removed['measure_unit'].replace(to_kg, 'KG')
df_food_removed['measure_unit']=df_food_removed['measure_unit'].replace(to_l, 'L')

# %%
df_food_removed.loc[df_food_removed['measure_unit'].isin(to_l)]
# Out:
# Empty DataFrame
# Columns: [date, market, latitude, longitude, category, commodity, unit, pricetype, currency, price, usdprice, iso, measure, measure_unit, product_name]
# Index: []

# %%
df_food_removed['measure_unit'].value_counts()
# Out:
# KG             2279014
# L               238433
# Unit             54099
# pcs              30011
# Head             25092
# Day              24104
# USD/LCU          15660
# Packet            9001
# Marmite           8379
# tablets           6750
# Loaf              3875
# piece             3635
# Bar               3557
# Bunch             2852
# Pair              2606
# GB                2415
# Course            2159
# Tubers            2051
# Sack              1807
# Dozen             1353
# Cylinder          1263
# ticket            1260
# sachet            1245
# Box               1194
# Bundle            1178
# Cubic meter       1079
# Brush             1026
# Dozens             337
# Package            269
# kWh                262
# Pile               244
# Month               88
# Heap                63
# Name: measure_unit, dtype: int64

# %%
# Changing the remaining units to Unit

df_food_removed.loc[~df_food_removed['measure_unit'].isin(['KG','L']), 'measure_unit'] = 'Unit'

# %%
df_food_removed['measure_unit'].value_counts()
# Out:
# KG      2279014
# L        238433
# Unit     208914
# Name: measure_unit, dtype: int64

# %%
#Checking for missing values

df_food_removed.isnull().sum() # missing values for price in $usd will be ignored for now
# Out:
# date                0
# market              0
# latitude        24268
# longitude       24268
# category            0
# commodity           0
# unit                0
# pricetype           0
# currency            0
# price               0
# usdprice         2740
# iso                 0
# measure             0
# measure_unit        0
# product_name        0
# dtype: int64

# %%
# Checking for records where price is 0. Exchange rate will be removed from the dataframe

df_food_removed.loc[df_food_removed['price']==0]
# Out:
#               date            market  latitude  longitude  category  \
# 3399682 2010-06-15  National Average       NaN        NaN  non-food
# 3399683 2010-07-15  National Average       NaN        NaN  non-food
# 3399684 2010-08-15  National Average       NaN        NaN  non-food
# 3399685 2010-09-15  National Average       NaN        NaN  non-food
# 3399686 2010-10-15  National Average       NaN        NaN  non-food
# 3399687 2010-11-15  National Average       NaN        NaN  non-food
# 3399688 2010-12-15  National Average       NaN        NaN  non-food
# 3399689 2011-01-15  National Average       NaN        NaN  non-food
# 3399690 2011-02-15  National Average       NaN        NaN  non-food
# 3399691 2011-03-15  National Average       NaN        NaN  non-food
# 3399692 2011-04-15  National Average       NaN        NaN  non-food
# 3399693 2011-05-15  National Average       NaN        NaN  non-food
# 3399694 2011-06-15  National Average       NaN        NaN  non-food
# 3399695 2011-07-15  National Average       NaN        NaN  non-food
# 3399696 2011-08-15  National Average       NaN        NaN  non-food
# 3399697 2011-09-15  National Average       NaN        NaN  non-food
# 3399698 2011-10-15  National Average       NaN        NaN  non-food
# 3399699 2011-11-15  National Average       NaN        NaN  non-food
# 3399700 2011-12-15  National Average       NaN        NaN  non-food
# 3399701 2012-01-15  National Average       NaN        NaN  non-food
# 3399702 2012-02-15  National Average       NaN        NaN  non-food
# 3399703 2012-03-15  National Average       NaN        NaN  non-food
# 3399704 2012-04-15  National Average       NaN        NaN  non-food
# 3399705 2012-05-15  National Average       NaN        NaN  non-food
# 3399706 2012-06-15  National Average       NaN        NaN  non-food
# 3399707 2012-07-15  National Average       NaN        NaN  non-food
# 3399708 2012-08-15  National Average       NaN        NaN  non-food
# 3399709 2012-09-15  National Average       NaN        NaN  non-food
# 3399710 2012-10-15  National Average       NaN        NaN  non-food
# 3399711 2012-11-15  National Average       NaN        NaN  non-food
# 3399712 2012-12-15  National Average       NaN        NaN  non-food
# 3399713 2013-01-15  National Average       NaN        NaN  non-food
# 3399714 2013-02-15  National Average       NaN        NaN  non-food
# 3399715 2013-04-15  National Average       NaN        NaN  non-food
# 3399716 2013-05-15  National Average       NaN        NaN  non-food
# 3399717 2013-06-15  National Average       NaN        NaN  non-food
# 3399718 2013-07-15  National Average       NaN        NaN  non-food
# 3399719 2013-08-15  National Average       NaN        NaN  non-food
# 3399720 2013-09-15  National Average       NaN        NaN  non-food
# 3399721 2013-10-15  National Average       NaN        NaN  non-food
# 3399722 2013-11-15  National Average       NaN        NaN  non-food
# 3399723 2013-12-15  National Average       NaN        NaN  non-food
# 3399724 2014-01-15  National Average       NaN        NaN  non-food
# 3399725 2014-02-15  National Average       NaN        NaN  non-food
# 3399726 2014-03-15  National Average       NaN        NaN  non-food
# 3399727 2014-04-15  National Average       NaN        NaN  non-food
# 3399728 2014-05-15  National Average       NaN        NaN  non-food
# 3399729 2014-06-15  National Average       NaN        NaN  non-food
# 3399730 2014-07-15  National Average       NaN        NaN  non-food
# 3399731 2014-08-15  National Average       NaN        NaN  non-food
# 3399732 2014-09-15  National Average       NaN        NaN  non-food
# 3399733 2014-10-15  National Average       NaN        NaN  non-food
# 3399734 2014-11-15  National Average       NaN        NaN  non-food
# 3399735 2014-12-15  National Average       NaN        NaN  non-food
# 3399736 2015-01-15  National Average       NaN        NaN  non-food
# 3399737 2015-02-15  National Average       NaN        NaN  non-food
# 3399738 2015-03-15  National Average       NaN        NaN  non-food
# 3399739 2015-04-15  National Average       NaN        NaN  non-food
# 3399740 2015-05-15  National Average       NaN        NaN  non-food
# 3399741 2015-06-15  National Average       NaN        NaN  non-food
#
#                           commodity     unit pricetype currency  price  \
# 3399682  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399683  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399684  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399685  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399686  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399687  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399688  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399689  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399690  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399691  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399692  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399693  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399694  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399695  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399696  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399697  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399698  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399699  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399700  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399701  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399702  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399703  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399704  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399705  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399706  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399707  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399708  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399709  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399710  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399711  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399712  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399713  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399714  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399715  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399716  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399717  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399718  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399719  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399720  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399721  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399722  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399723  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399724  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399725  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399726  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399727  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399728  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399729  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399730  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399731  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399732  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399733  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399734  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399735  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399736  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399737  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399738  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399739  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399740  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
# 3399741  Exchange rate (unofficial)  USD/LCU    Retail      VEF    0.0
#
#          usdprice  iso  measure measure_unit   product_name
# 3399682    0.0000  VEN      1.0         Unit  Exchange rate
# 3399683    0.0000  VEN      1.0         Unit  Exchange rate
# 3399684    0.0000  VEN      1.0         Unit  Exchange rate
# 3399685    0.0000  VEN      1.0         Unit  Exchange rate
# 3399686    0.0000  VEN      1.0         Unit  Exchange rate
# 3399687    0.0000  VEN      1.0         Unit  Exchange rate
# 3399688    0.0000  VEN      1.0         Unit  Exchange rate
# 3399689    0.0000  VEN      1.0         Unit  Exchange rate
# 3399690    0.0000  VEN      1.0         Unit  Exchange rate
# 3399691    0.0000  VEN      1.0         Unit  Exchange rate
# 3399692    0.0000  VEN      1.0         Unit  Exchange rate
# 3399693    0.0000  VEN      1.0         Unit  Exchange rate
# 3399694    0.0000  VEN      1.0         Unit  Exchange rate
# 3399695    0.0000  VEN      1.0         Unit  Exchange rate
# 3399696    0.0000  VEN      1.0         Unit  Exchange rate
# 3399697    0.0000  VEN      1.0         Unit  Exchange rate
# 3399698    0.0000  VEN      1.0         Unit  Exchange rate
# 3399699    0.0000  VEN      1.0         Unit  Exchange rate
# 3399700    0.0000  VEN      1.0         Unit  Exchange rate
# 3399701    0.0000  VEN      1.0         Unit  Exchange rate
# 3399702    0.0000  VEN      1.0         Unit  Exchange rate
# 3399703    0.0000  VEN      1.0         Unit  Exchange rate
# 3399704    0.0000  VEN      1.0         Unit  Exchange rate
# 3399705    0.0000  VEN      1.0         Unit  Exchange rate
# 3399706    0.0000  VEN      1.0         Unit  Exchange rate
# 3399707    0.0000  VEN      1.0         Unit  Exchange rate
# 3399708    0.0000  VEN      1.0         Unit  Exchange rate
# 3399709    0.0000  VEN      1.0         Unit  Exchange rate
# 3399710    0.0000  VEN      1.0         Unit  Exchange rate
# 3399711    0.0000  VEN      1.0         Unit  Exchange rate
# 3399712    0.0000  VEN      1.0         Unit  Exchange rate
# 3399713    0.0000  VEN      1.0         Unit  Exchange rate
# 3399714    0.0000  VEN      1.0         Unit  Exchange rate
# 3399715    0.0000  VEN      1.0         Unit  Exchange rate
# 3399716    0.0000  VEN      1.0         Unit  Exchange rate
# 3399717    0.0000  VEN      1.0         Unit  Exchange rate
# 3399718    0.0000  VEN      1.0         Unit  Exchange rate
# 3399719    0.0000  VEN      1.0         Unit  Exchange rate
# 3399720    0.0000  VEN      1.0         Unit  Exchange rate
# 3399721    0.0001  VEN      1.0         Unit  Exchange rate
# 3399722    0.0001  VEN      1.0         Unit  Exchange rate
# 3399723    0.0000  VEN      1.0         Unit  Exchange rate
# 3399724    0.0001  VEN      1.0         Unit  Exchange rate
# 3399725    0.0000  VEN      1.0         Unit  Exchange rate
# 3399726    0.0000  VEN      1.0         Unit  Exchange rate
# 3399727    0.0001  VEN      1.0         Unit  Exchange rate
# 3399728    0.0001  VEN      1.0         Unit  Exchange rate
# 3399729    0.0000  VEN      1.0         Unit  Exchange rate
# 3399730    0.0001  VEN      1.0         Unit  Exchange rate
# 3399731    0.0001  VEN      1.0         Unit  Exchange rate
# 3399732    0.0002  VEN      1.0         Unit  Exchange rate
# 3399733    0.0002  VEN      1.0         Unit  Exchange rate
# 3399734    0.0000  VEN      1.0         Unit  Exchange rate
# 3399735    0.0003  VEN      1.0         Unit  Exchange rate
# 3399736    0.0003  VEN      1.0         Unit  Exchange rate
# 3399737    0.0000  VEN      1.0         Unit  Exchange rate
# 3399738    0.0000  VEN      1.0         Unit  Exchange rate
# 3399739    0.0004  VEN      1.0         Unit  Exchange rate
# 3399740    0.0005  VEN      1.0         Unit  Exchange rate
# 3399741    0.0007  VEN      1.0         Unit  Exchange rate

# %%
df_food_removed=df_food_removed[df_food_removed['price']!=0]

# %%
df_food_removed.reset_index(inplace=True)

# %%
df_food_removed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2726301 entries, 0 to 2726300
# Data columns (total 16 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   index         int64
#  1   date          datetime64[ns]
#  2   market        object
#  3   latitude      float64
#  4   longitude     float64
#  5   category      object
#  6   commodity     object
#  7   unit          object
#  8   pricetype     object
#  9   currency      object
#  10  price         float64
#  11  usdprice      float64
#  12  iso           object
#  13  measure       float64
#  14  measure_unit  object
#  15  product_name  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# memory usage: 332.8+ MB

# %%
# Checking for duplicates

df_food_removed.duplicated().value_counts()

# in the original data set, the same price measure was taken at the same time in different locations and for the same products of different types
# Out:
# False    2726301
# dtype: int64

# %% [markdown]
# The duplicates will be handled according to the following plan:
#
# 1. Calculate price per unit for each product
# 2. Calculate average price for the same product name on a country-year-month level

# %%
# Calculating price per unit in local currency and usd

df_food_removed['price_unit']=df_food_removed['price']/df_food_removed['measure']
df_food_removed['usdprice_unit']=df_food_removed['usdprice']/df_food_removed['measure']

# %%
# Removing measure column

df_food_removed.drop(columns=['measure','index'],inplace=True)

# %%
df_food_removed.head()
# Out:
#         date    market   latitude  longitude            category  \
# 0 2000-01-15  Fayzabad  37.116638  70.580022            non-food
# 1 2000-01-15     Mazar  36.725116  67.109571            non-food
# 2 2000-01-15     Hirat  34.346944  62.198333  cereals and tubers
# 3 2000-01-15     Hirat  34.346944  62.198333  cereals and tubers
# 4 2000-01-15     Hirat  34.346944  62.198333  cereals and tubers
#
#                                        commodity unit pricetype currency  \
# 0  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 1  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 2                                          Bread   KG    Retail      AFN
# 3                                          Wheat   KG    Retail      AFN
# 4                                    Wheat flour   KG    Retail      AFN
#
#        price   usdprice  iso measure_unit product_name  price_unit  \
# 0  150000.00  3205.7378  AFG         Unit         Wage   150000.00
# 1  100000.00  2137.1586  AFG         Unit         Wage   100000.00
# 2      15.63     0.3340  AFG           KG        Bread       15.63
# 3       9.13     0.1951  AFG           KG        Wheat        9.13
# 4      10.06     0.2150  AFG           KG  Wheat flour       10.06
#
#    usdprice_unit
# 0      3205.7378
# 1      2137.1586
# 2         0.3340
# 3         0.1951
# 4         0.2150

# %%
# Checking if any products have been measured multiple times using various measure units

df_mult_units=df_food_removed.groupby('product_name')['measure_unit'].nunique().sort_values(ascending=False).rename_axis('product').reset_index(name='count')

# %%
df_mult_units=df_mult_units[df_mult_units['count']>1]
df_mult_units #for 51 products, multiple units are used for measuring
# Out:
#               product  count
# 0             Noodles      3
# 1                Rice      3
# 2       Handwash soap      3
# 3                Wage      3
# 4                Fuel      3
# 5                Salt      2
# 6                Fish      2
# 7            Firewood      2
# 8                Eggs      2
# 9          Maize meal      2
# 10         Sour cream      2
# 11          Cucumbers      2
# 12            Spinach      2
# 13              Sugar      2
# 14             Coffee      2
# 15            Coconut      2
# 16            Chicken      2
# 17             Garlic      2
# 18         Groundnuts      2
# 19           Charcoal      2
# 20            Lettuce      2
# 21                Oil      2
# 22             Onions      2
# 23            Parsley      2
# 24               Milk      2
# 25               Meat      2
# 26              Pasta      2
# 27          Plantains      2
# 28             Radish      2
# 29       Laundry soap      2
# 30  Laundry detergent      2
# 31      Potato Leaves      2
# 32           Potatoes      2
# 33               Kale      2
# 34      Powdered milk      2
# 35             Cheese      2
# 36            Sorghum      2
# 37        Cauliflower      2
# 38            Cabbage      2
# 39             Yogurt      2
# 40                Yam      2
# 41           Avocados      2
# 42            Bananas      2
# 43        Wheat flour      2
# 44              Beans      2
# 45             Bleach      2
# 46              Water      2
# 47                Tea      2
# 48           Broccoli      2
# 49              Bread      2
# 50     Cassava leaves      2
# 51           Tomatoes      2

# %% [markdown]
# Using different measure units will complicate further analysis. I will handle it using the following logic:
#
# 1. For bread unit will be converted into KG and the price will be duplicated, since a loaf of bread is typically about 500g
# 2. For yogurt and sour cream unit will be converted into L and the price will be duplicated since a typical unit is usually about 0.5 L
# 3. For other products units will be converted 1 to 1 though it might skew the results. But I don't have any way to check what ws the actual weight of the unit recorded

# %%
# Creating a list of products we need to handle

list=df_mult_units['product'].to_list()

# %%
df_food_removed[df_food_removed['product_name']=='Noodles'].head(80)
# Out:
#              date           market   latitude  longitude            category  \
# 278383 2010-01-15         Trinidad -14.837491 -64.904286  cereals and tubers
# 278393 2010-01-15            Sucre -19.043056 -65.259167  cereals and tubers
# 278405 2010-01-15  Cochabamba City -17.389498 -66.156797  cereals and tubers
# 278422 2010-01-15      La Paz City -16.500000 -68.150000  cereals and tubers
# 278438 2010-01-15       Oruro City -17.983333 -67.150000  cereals and tubers
# ...           ...              ...        ...        ...                 ...
# 279392 2010-09-15      La Paz City -16.500000 -68.150000  cereals and tubers
# 279410 2010-09-15       Oruro City -17.983333 -67.150000  cereals and tubers
# 279426 2010-09-15           Cobija -11.783333 -67.900000  cereals and tubers
# 279432 2010-09-15           Potosi -19.583611 -65.753056  cereals and tubers
# 279444 2010-09-15  Santa Cruz City -17.814582 -63.156085  cereals and tubers
#
#               commodity       unit pricetype currency  price  usdprice  iso  \
# 278383  Noodles (short)         KG    Retail      BOB   7.75    1.1260  BOL
# 278393  Noodles (short)         KG    Retail      BOB   6.95    1.0097  BOL
# 278405  Noodles (short)      Pound    Retail      BOB   3.61    0.5245  BOL
# 278422  Noodles (short)      Pound    Retail      BOB   3.36    0.4882  BOL
# 278438  Noodles (short)         KG    Retail      BOB   7.00    1.0170  BOL
# ...                 ...        ...       ...      ...    ...       ...  ...
# 279392  Noodles (short)      Pound    Retail      BOB   3.44    0.5011  BOL
# 279410  Noodles (short)         KG    Retail      BOB   7.42    1.0808  BOL
# 279426  Noodles (short)         KG    Retail      BOB  14.00    2.0392  BOL
# 279432  Noodles (short)  Cuartilla    Retail      BOB  17.72    2.5811  BOL
# 279444  Noodles (short)         KG    Retail      BOB   7.64    1.1128  BOL
#
#        measure_unit product_name  price_unit  usdprice_unit
# 278383           KG      Noodles    7.750000       1.126000
# 278393           KG      Noodles    6.950000       1.009700
# 278405           KG      Noodles    8.022222       1.165556
# 278422           KG      Noodles    7.466667       1.084889
# 278438           KG      Noodles    7.000000       1.017000
# ...             ...          ...         ...            ...
# 279392           KG      Noodles    7.644444       1.113556
# 279410           KG      Noodles    7.420000       1.080800
# 279426           KG      Noodles   14.000000       2.039200
# 279432            L      Noodles    1.274820       0.185691
# 279444           KG      Noodles    7.640000       1.112800
#
# [80 rows x 16 columns]

# %%
# Changing bread price

df_food_removed.loc[(df_food_removed['measure_unit']=='Unit')&(df_food_removed['product_name']=='Bread'), 'price_unit']=df_food_removed['price_unit']*2
df_food_removed.loc[(df_food_removed['measure_unit']=='Unit')&(df_food_removed['product_name']=='Bread'), 'usdprice_unit']=df_food_removed['usdprice_unit']*2

# %%
# Changing yogurt and sour cream price

df_food_removed.loc[(df_food_removed['measure_unit']=='Unit')&(df_food_removed['product_name'].isin(['Sour cream','Yogurt'])), 'price_unit']=df_food_removed['price_unit']*2
df_food_removed.loc[(df_food_removed['measure_unit']=='Unit')&(df_food_removed['product_name'].isin(['Sour cream','Yogurt'])), 'usdprice_unit']=df_food_removed['usdprice_unit']*2

# %%
# Changing measure units for bread, sour cream and yogurt

df_food_removed.loc[df_food_removed['product_name'].isin(['Sour cream','Yogurt']), 'measure_unit']='L'
df_food_removed.loc[df_food_removed['product_name'].isin(['Bread']), 'measure_unit']='KG'

# %%
df_mult_units=df_food_removed.groupby('product_name')['measure_unit'].nunique().sort_values(ascending=False).rename_axis('product').reset_index(name='count')
df_mult_units=df_mult_units[df_mult_units['count']>1]
df_mult_units #for 51 products, multiple units are used for measuring
# Out:
#               product  count
# 0                Fuel      3
# 1                Rice      3
# 2       Handwash soap      3
# 3             Noodles      3
# 4                Wage      3
# 5       Potato Leaves      2
# 6              Garlic      2
# 7            Charcoal      2
# 8              Cheese      2
# 9             Chicken      2
# 10          Plantains      2
# 11       Laundry soap      2
# 12  Laundry detergent      2
# 13            Coconut      2
# 14             Coffee      2
# 15              Sugar      2
# 16           Potatoes      2
# 17               Kale      2
# 18                Tea      2
# 19            Spinach      2
# 20      Powdered milk      2
# 21          Cucumbers      2
# 22            Sorghum      2
# 23               Eggs      2
# 24         Groundnuts      2
# 25             Radish      2
# 26           Firewood      2
# 27               Fish      2
# 28               Salt      2
# 29     Cassava leaves      2
# 30         Maize meal      2
# 31            Parsley      2
# 32           Broccoli      2
# 33                Oil      2
# 34             Onions      2
# 35                Yam      2
# 36           Avocados      2
# 37            Bananas      2
# 38        Wheat flour      2
# 39              Beans      2
# 40               Milk      2
# 41           Tomatoes      2
# 42               Meat      2
# 43             Bleach      2
# 44              Water      2
# 45        Cauliflower      2
# 46            Lettuce      2
# 47              Pasta      2
# 48            Cabbage      2

# %%
# for all other product I will calculate the most popular (mode) measure unit and use at as the only measure unit for a certain product

# Finding the most common measure unit for each product 

df_food_removed['measure_mode']=df_food_removed.groupby('product_name')['measure_unit'].transform(lambda x: x.value_counts().idxmax())
df_food_removed.head(50)
# Out:
#          date     market   latitude  longitude            category  \
# 0  2000-01-15   Fayzabad  37.116638  70.580022            non-food
# 1  2000-01-15      Mazar  36.725116  67.109571            non-food
# 2  2000-01-15      Hirat  34.346944  62.198333  cereals and tubers
# 3  2000-01-15      Hirat  34.346944  62.198333  cereals and tubers
# 4  2000-01-15      Hirat  34.346944  62.198333  cereals and tubers
# 5  2000-01-15      Hirat  34.346944  62.198333            non-food
# 6  2000-01-15      Kabul  34.516667  69.183333  cereals and tubers
# 7  2000-01-15      Kabul  34.516667  69.183333  cereals and tubers
# 8  2000-01-15      Kabul  34.516667  69.183333  cereals and tubers
# 9  2000-01-15      Kabul  34.516667  69.183333            non-food
# 10 2000-01-15   Kandahar  31.612500  65.709444  cereals and tubers
# 11 2000-01-15   Kandahar  31.612500  65.709444  cereals and tubers
# 12 2000-01-15   Kandahar  31.612500  65.709444  cereals and tubers
# 13 2000-01-15   Kandahar  31.612500  65.709444            non-food
# 14 2000-01-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 15 2000-01-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 16 2000-01-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 17 2000-01-15  Jalalabad  34.426111  70.451389            non-food
# 18 2000-02-15   Fayzabad  37.116638  70.580022            non-food
# 19 2000-02-15      Mazar  36.725116  67.109571            non-food
# 20 2000-02-15      Hirat  34.346944  62.198333  cereals and tubers
# 21 2000-02-15      Hirat  34.346944  62.198333  cereals and tubers
# 22 2000-02-15      Hirat  34.346944  62.198333  cereals and tubers
# 23 2000-02-15      Hirat  34.346944  62.198333            non-food
# 24 2000-02-15      Kabul  34.516667  69.183333  cereals and tubers
# 25 2000-02-15      Kabul  34.516667  69.183333  cereals and tubers
# 26 2000-02-15      Kabul  34.516667  69.183333  cereals and tubers
# 27 2000-02-15      Kabul  34.516667  69.183333            non-food
# 28 2000-02-15   Kandahar  31.612500  65.709444  cereals and tubers
# 29 2000-02-15   Kandahar  31.612500  65.709444  cereals and tubers
# 30 2000-02-15   Kandahar  31.612500  65.709444  cereals and tubers
# 31 2000-02-15   Kandahar  31.612500  65.709444            non-food
# 32 2000-02-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 33 2000-02-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 34 2000-02-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 35 2000-02-15  Jalalabad  34.426111  70.451389            non-food
# 36 2000-03-15   Fayzabad  37.116638  70.580022            non-food
# 37 2000-03-15   Fayzabad  37.116638  70.580022            non-food
# 38 2000-03-15      Mazar  36.725116  67.109571            non-food
# 39 2000-03-15      Mazar  36.725116  67.109571            non-food
# 40 2000-03-15      Hirat  34.346944  62.198333  cereals and tubers
# 41 2000-03-15      Hirat  34.346944  62.198333  cereals and tubers
# 42 2000-03-15      Hirat  34.346944  62.198333  cereals and tubers
# 43 2000-03-15      Hirat  34.346944  62.198333            non-food
# 44 2000-03-15      Hirat  34.346944  62.198333            non-food
# 45 2000-03-15      Kabul  34.516667  69.183333  cereals and tubers
# 46 2000-03-15      Kabul  34.516667  69.183333  cereals and tubers
# 47 2000-03-15      Kabul  34.516667  69.183333  cereals and tubers
# 48 2000-03-15      Kabul  34.516667  69.183333            non-food
# 49 2000-03-15      Kabul  34.516667  69.183333            non-food
#
#                                         commodity unit pricetype currency  \
# 0   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 1   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 2                                           Bread   KG    Retail      AFN
# 3                                           Wheat   KG    Retail      AFN
# 4                                     Wheat flour   KG    Retail      AFN
# 5   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 6                                           Bread   KG    Retail      AFN
# 7                                           Wheat   KG    Retail      AFN
# 8                                     Wheat flour   KG    Retail      AFN
# 9   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 10                                          Bread   KG    Retail      AFN
# 11                                          Wheat   KG    Retail      AFN
# 12                                    Wheat flour   KG    Retail      AFN
# 13  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 14                                          Bread   KG    Retail      AFN
# 15                                          Wheat   KG    Retail      AFN
# 16                                    Wheat flour   KG    Retail      AFN
# 17  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 18  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 19  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 20                                          Bread   KG    Retail      AFN
# 21                                          Wheat   KG    Retail      AFN
# 22                                    Wheat flour   KG    Retail      AFN
# 23  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 24                                          Bread   KG    Retail      AFN
# 25                                          Wheat   KG    Retail      AFN
# 26                                    Wheat flour   KG    Retail      AFN
# 27  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 28                                          Bread   KG    Retail      AFN
# 29                                          Wheat   KG    Retail      AFN
# 30                                    Wheat flour   KG    Retail      AFN
# 31  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 32                                          Bread   KG    Retail      AFN
# 33                                          Wheat   KG    Retail      AFN
# 34                                    Wheat flour   KG    Retail      AFN
# 35  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 36                                  Fuel (diesel)    L    Retail      AFN
# 37  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 38                                  Fuel (diesel)    L    Retail      AFN
# 39  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 40                                          Bread   KG    Retail      AFN
# 41                                          Wheat   KG    Retail      AFN
# 42                                    Wheat flour   KG    Retail      AFN
# 43                                  Fuel (diesel)    L    Retail      AFN
# 44  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 45                                          Bread   KG    Retail      AFN
# 46                                          Wheat   KG    Retail      AFN
# 47                                    Wheat flour   KG    Retail      AFN
# 48                                  Fuel (diesel)    L    Retail      AFN
# 49  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
#
#         price   usdprice  iso measure_unit product_name  price_unit  \
# 0   150000.00  3205.7378  AFG         Unit         Wage   150000.00
# 1   100000.00  2137.1586  AFG         Unit         Wage   100000.00
# 2       15.63     0.3340  AFG           KG        Bread       15.63
# 3        9.13     0.1951  AFG           KG        Wheat        9.13
# 4       10.06     0.2150  AFG           KG  Wheat flour       10.06
# 5    60000.00  1282.2951  AFG         Unit         Wage    60000.00
# 6       14.26     0.3048  AFG           KG        Bread       14.26
# 7       13.75     0.2939  AFG           KG        Wheat       13.75
# 8       18.57     0.3969  AFG           KG  Wheat flour       18.57
# 9    55000.00  1175.4372  AFG         Unit         Wage    55000.00
# 10      16.25     0.3473  AFG           KG        Bread       16.25
# 11      12.88     0.2753  AFG           KG        Wheat       12.88
# 12      18.00     0.3847  AFG           KG  Wheat flour       18.00
# 13   75000.00  1602.8689  AFG         Unit         Wage    75000.00
# 14      14.86     0.3176  AFG           KG        Bread       14.86
# 15      13.16     0.2813  AFG           KG        Wheat       13.16
# 16      15.55     0.3323  AFG           KG  Wheat flour       15.55
# 17   58749.50  1255.5700  AFG         Unit         Wage    58749.50
# 18  150000.00  3180.6047  AFG         Unit         Wage   150000.00
# 19  100000.00  2120.4031  AFG         Unit         Wage   100000.00
# 20      15.63     0.3314  AFG           KG        Bread       15.63
# 21       9.13     0.1936  AFG           KG        Wheat        9.13
# 22       9.88     0.2095  AFG           KG  Wheat flour        9.88
# 23   60000.00  1272.2419  AFG         Unit         Wage    60000.00
# 24      13.49     0.2860  AFG           KG        Bread       13.49
# 25      12.32     0.2612  AFG           KG        Wheat       12.32
# 26      16.07     0.3407  AFG           KG  Wheat flour       16.07
# 27   70000.00  1484.2822  AFG         Unit         Wage    70000.00
# 28      15.42     0.3270  AFG           KG        Bread       15.42
# 29      12.23     0.2593  AFG           KG        Wheat       12.23
# 30      16.38     0.3473  AFG           KG  Wheat flour       16.38
# 31   75000.00  1590.3023  AFG         Unit         Wage    75000.00
# 32      16.66     0.3533  AFG           KG        Bread       16.66
# 33      13.31     0.2822  AFG           KG        Wheat       13.31
# 34      15.38     0.3261  AFG           KG  Wheat flour       15.38
# 35   59999.50  1272.2313  AFG         Unit         Wage    59999.50
# 36   50000.00  1055.0656  AFG            L         Fuel    50000.00
# 37  116250.00  2453.0274  AFG         Unit         Wage   116250.00
# 38   34250.00   722.7199  AFG            L         Fuel    34250.00
# 39  100000.00  2110.1311  AFG         Unit         Wage   100000.00
# 40      16.14     0.3406  AFG           KG        Bread       16.14
# 41       8.82     0.1861  AFG           KG        Wheat        8.82
# 42      10.23     0.2159  AFG           KG  Wheat flour       10.23
# 43   16000.00   337.6210  AFG            L         Fuel    16000.00
# 44   60000.00  1266.0787  AFG         Unit         Wage    60000.00
# 45      11.76     0.2482  AFG           KG        Bread       11.76
# 46      11.72     0.2473  AFG           KG        Wheat       11.72
# 47      14.25     0.3007  AFG           KG  Wheat flour       14.25
# 48   12075.00   254.7983  AFG            L         Fuel    12075.00
# 49   70000.00  1477.0918  AFG         Unit         Wage    70000.00
#
#     usdprice_unit measure_mode
# 0       3205.7378         Unit
# 1       2137.1586         Unit
# 2          0.3340           KG
# 3          0.1951           KG
# 4          0.2150           KG
# 5       1282.2951         Unit
# 6          0.3048           KG
# 7          0.2939           KG
# 8          0.3969           KG
# 9       1175.4372         Unit
# 10         0.3473           KG
# 11         0.2753           KG
# 12         0.3847           KG
# 13      1602.8689         Unit
# 14         0.3176           KG
# 15         0.2813           KG
# 16         0.3323           KG
# 17      1255.5700         Unit
# 18      3180.6047         Unit
# 19      2120.4031         Unit
# 20         0.3314           KG
# 21         0.1936           KG
# 22         0.2095           KG
# 23      1272.2419         Unit
# 24         0.2860           KG
# 25         0.2612           KG
# 26         0.3407           KG
# 27      1484.2822         Unit
# 28         0.3270           KG
# 29         0.2593           KG
# 30         0.3473           KG
# 31      1590.3023         Unit
# 32         0.3533           KG
# 33         0.2822           KG
# 34         0.3261           KG
# 35      1272.2313         Unit
# 36      1055.0656            L
# 37      2453.0274         Unit
# 38       722.7199            L
# 39      2110.1311         Unit
# 40         0.3406           KG
# 41         0.1861           KG
# 42         0.2159           KG
# 43       337.6210            L
# 44      1266.0787         Unit
# 45         0.2482           KG
# 46         0.2473           KG
# 47         0.3007           KG
# 48       254.7983            L
# 49      1477.0918         Unit

# %%
#Replacing measure unit with the most popular one for each product

df_food_removed['measure_unit']=df_food_removed['measure_mode']

# %%
df_food_removed.groupby('product_name')['measure_unit'].nunique().sort_values(ascending=False) #Fixed!
# Out:
# product_name
# Alcohol          1
# Potato Leaves    1
# Peas             1
# Pen              1
# Pencil           1
#                 ..
# Fuel             1
# Gari             1
# Garlic           1
# Ghee             1
# Zucchini         1
# Name: measure_unit, Length: 202, dtype: int64

# %% [markdown]
# ### Handling multiple categories

# %%
# I will handle double categories the same way

# Checking if the same product is always recorded in the same category

df_food_removed.groupby('product_name')['category'].nunique().sort_values(ascending=False)
# Out:
# product_name
# Groundnuts    2
# Tomatoes      2
# Lemons        2
# Beans         2
# Peas          2
#              ..
# Fuel          1
# Gari          1
# Garlic        1
# Ghee          1
# Zucchini      1
# Name: category, Length: 202, dtype: int64

# %%
# Finding the most common category for each product 

df_food_removed['category_mode']=df_food_removed.groupby('product_name')['category'].transform(lambda x: x.value_counts().idxmax())
df_food_removed.head(50)
# Out:
#          date     market   latitude  longitude            category  \
# 0  2000-01-15   Fayzabad  37.116638  70.580022            non-food
# 1  2000-01-15      Mazar  36.725116  67.109571            non-food
# 2  2000-01-15      Hirat  34.346944  62.198333  cereals and tubers
# 3  2000-01-15      Hirat  34.346944  62.198333  cereals and tubers
# 4  2000-01-15      Hirat  34.346944  62.198333  cereals and tubers
# 5  2000-01-15      Hirat  34.346944  62.198333            non-food
# 6  2000-01-15      Kabul  34.516667  69.183333  cereals and tubers
# 7  2000-01-15      Kabul  34.516667  69.183333  cereals and tubers
# 8  2000-01-15      Kabul  34.516667  69.183333  cereals and tubers
# 9  2000-01-15      Kabul  34.516667  69.183333            non-food
# 10 2000-01-15   Kandahar  31.612500  65.709444  cereals and tubers
# 11 2000-01-15   Kandahar  31.612500  65.709444  cereals and tubers
# 12 2000-01-15   Kandahar  31.612500  65.709444  cereals and tubers
# 13 2000-01-15   Kandahar  31.612500  65.709444            non-food
# 14 2000-01-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 15 2000-01-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 16 2000-01-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 17 2000-01-15  Jalalabad  34.426111  70.451389            non-food
# 18 2000-02-15   Fayzabad  37.116638  70.580022            non-food
# 19 2000-02-15      Mazar  36.725116  67.109571            non-food
# 20 2000-02-15      Hirat  34.346944  62.198333  cereals and tubers
# 21 2000-02-15      Hirat  34.346944  62.198333  cereals and tubers
# 22 2000-02-15      Hirat  34.346944  62.198333  cereals and tubers
# 23 2000-02-15      Hirat  34.346944  62.198333            non-food
# 24 2000-02-15      Kabul  34.516667  69.183333  cereals and tubers
# 25 2000-02-15      Kabul  34.516667  69.183333  cereals and tubers
# 26 2000-02-15      Kabul  34.516667  69.183333  cereals and tubers
# 27 2000-02-15      Kabul  34.516667  69.183333            non-food
# 28 2000-02-15   Kandahar  31.612500  65.709444  cereals and tubers
# 29 2000-02-15   Kandahar  31.612500  65.709444  cereals and tubers
# 30 2000-02-15   Kandahar  31.612500  65.709444  cereals and tubers
# 31 2000-02-15   Kandahar  31.612500  65.709444            non-food
# 32 2000-02-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 33 2000-02-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 34 2000-02-15  Jalalabad  34.426111  70.451389  cereals and tubers
# 35 2000-02-15  Jalalabad  34.426111  70.451389            non-food
# 36 2000-03-15   Fayzabad  37.116638  70.580022            non-food
# 37 2000-03-15   Fayzabad  37.116638  70.580022            non-food
# 38 2000-03-15      Mazar  36.725116  67.109571            non-food
# 39 2000-03-15      Mazar  36.725116  67.109571            non-food
# 40 2000-03-15      Hirat  34.346944  62.198333  cereals and tubers
# 41 2000-03-15      Hirat  34.346944  62.198333  cereals and tubers
# 42 2000-03-15      Hirat  34.346944  62.198333  cereals and tubers
# 43 2000-03-15      Hirat  34.346944  62.198333            non-food
# 44 2000-03-15      Hirat  34.346944  62.198333            non-food
# 45 2000-03-15      Kabul  34.516667  69.183333  cereals and tubers
# 46 2000-03-15      Kabul  34.516667  69.183333  cereals and tubers
# 47 2000-03-15      Kabul  34.516667  69.183333  cereals and tubers
# 48 2000-03-15      Kabul  34.516667  69.183333            non-food
# 49 2000-03-15      Kabul  34.516667  69.183333            non-food
#
#                                         commodity unit pricetype currency  \
# 0   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 1   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 2                                           Bread   KG    Retail      AFN
# 3                                           Wheat   KG    Retail      AFN
# 4                                     Wheat flour   KG    Retail      AFN
# 5   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 6                                           Bread   KG    Retail      AFN
# 7                                           Wheat   KG    Retail      AFN
# 8                                     Wheat flour   KG    Retail      AFN
# 9   Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 10                                          Bread   KG    Retail      AFN
# 11                                          Wheat   KG    Retail      AFN
# 12                                    Wheat flour   KG    Retail      AFN
# 13  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 14                                          Bread   KG    Retail      AFN
# 15                                          Wheat   KG    Retail      AFN
# 16                                    Wheat flour   KG    Retail      AFN
# 17  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 18  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 19  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 20                                          Bread   KG    Retail      AFN
# 21                                          Wheat   KG    Retail      AFN
# 22                                    Wheat flour   KG    Retail      AFN
# 23  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 24                                          Bread   KG    Retail      AFN
# 25                                          Wheat   KG    Retail      AFN
# 26                                    Wheat flour   KG    Retail      AFN
# 27  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 28                                          Bread   KG    Retail      AFN
# 29                                          Wheat   KG    Retail      AFN
# 30                                    Wheat flour   KG    Retail      AFN
# 31  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 32                                          Bread   KG    Retail      AFN
# 33                                          Wheat   KG    Retail      AFN
# 34                                    Wheat flour   KG    Retail      AFN
# 35  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 36                                  Fuel (diesel)    L    Retail      AFN
# 37  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 38                                  Fuel (diesel)    L    Retail      AFN
# 39  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 40                                          Bread   KG    Retail      AFN
# 41                                          Wheat   KG    Retail      AFN
# 42                                    Wheat flour   KG    Retail      AFN
# 43                                  Fuel (diesel)    L    Retail      AFN
# 44  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
# 45                                          Bread   KG    Retail      AFN
# 46                                          Wheat   KG    Retail      AFN
# 47                                    Wheat flour   KG    Retail      AFN
# 48                                  Fuel (diesel)    L    Retail      AFN
# 49  Wage (non-qualified labour, non-agricultural)  Day    Retail      AFN
#
#         price   usdprice  iso measure_unit product_name  price_unit  \
# 0   150000.00  3205.7378  AFG         Unit         Wage   150000.00
# 1   100000.00  2137.1586  AFG         Unit         Wage   100000.00
# 2       15.63     0.3340  AFG           KG        Bread       15.63
# 3        9.13     0.1951  AFG           KG        Wheat        9.13
# 4       10.06     0.2150  AFG           KG  Wheat flour       10.06
# 5    60000.00  1282.2951  AFG         Unit         Wage    60000.00
# 6       14.26     0.3048  AFG           KG        Bread       14.26
# 7       13.75     0.2939  AFG           KG        Wheat       13.75
# 8       18.57     0.3969  AFG           KG  Wheat flour       18.57
# 9    55000.00  1175.4372  AFG         Unit         Wage    55000.00
# 10      16.25     0.3473  AFG           KG        Bread       16.25
# 11      12.88     0.2753  AFG           KG        Wheat       12.88
# 12      18.00     0.3847  AFG           KG  Wheat flour       18.00
# 13   75000.00  1602.8689  AFG         Unit         Wage    75000.00
# 14      14.86     0.3176  AFG           KG        Bread       14.86
# 15      13.16     0.2813  AFG           KG        Wheat       13.16
# 16      15.55     0.3323  AFG           KG  Wheat flour       15.55
# 17   58749.50  1255.5700  AFG         Unit         Wage    58749.50
# 18  150000.00  3180.6047  AFG         Unit         Wage   150000.00
# 19  100000.00  2120.4031  AFG         Unit         Wage   100000.00
# 20      15.63     0.3314  AFG           KG        Bread       15.63
# 21       9.13     0.1936  AFG           KG        Wheat        9.13
# 22       9.88     0.2095  AFG           KG  Wheat flour        9.88
# 23   60000.00  1272.2419  AFG         Unit         Wage    60000.00
# 24      13.49     0.2860  AFG           KG        Bread       13.49
# 25      12.32     0.2612  AFG           KG        Wheat       12.32
# 26      16.07     0.3407  AFG           KG  Wheat flour       16.07
# 27   70000.00  1484.2822  AFG         Unit         Wage    70000.00
# 28      15.42     0.3270  AFG           KG        Bread       15.42
# 29      12.23     0.2593  AFG           KG        Wheat       12.23
# 30      16.38     0.3473  AFG           KG  Wheat flour       16.38
# 31   75000.00  1590.3023  AFG         Unit         Wage    75000.00
# 32      16.66     0.3533  AFG           KG        Bread       16.66
# 33      13.31     0.2822  AFG           KG        Wheat       13.31
# 34      15.38     0.3261  AFG           KG  Wheat flour       15.38
# 35   59999.50  1272.2313  AFG         Unit         Wage    59999.50
# 36   50000.00  1055.0656  AFG            L         Fuel    50000.00
# 37  116250.00  2453.0274  AFG         Unit         Wage   116250.00
# 38   34250.00   722.7199  AFG            L         Fuel    34250.00
# 39  100000.00  2110.1311  AFG         Unit         Wage   100000.00
# 40      16.14     0.3406  AFG           KG        Bread       16.14
# 41       8.82     0.1861  AFG           KG        Wheat        8.82
# 42      10.23     0.2159  AFG           KG  Wheat flour       10.23
# 43   16000.00   337.6210  AFG            L         Fuel    16000.00
# 44   60000.00  1266.0787  AFG         Unit         Wage    60000.00
# 45      11.76     0.2482  AFG           KG        Bread       11.76
# 46      11.72     0.2473  AFG           KG        Wheat       11.72
# 47      14.25     0.3007  AFG           KG  Wheat flour       14.25
# 48   12075.00   254.7983  AFG            L         Fuel    12075.00
# 49   70000.00  1477.0918  AFG         Unit         Wage    70000.00
#
#     usdprice_unit measure_mode       category_mode
# 0       3205.7378         Unit            non-food
# 1       2137.1586         Unit            non-food
# 2          0.3340           KG  cereals and tubers
# 3          0.1951           KG  cereals and tubers
# 4          0.2150           KG  cereals and tubers
# 5       1282.2951         Unit            non-food
# 6          0.3048           KG  cereals and tubers
# 7          0.2939           KG  cereals and tubers
# 8          0.3969           KG  cereals and tubers
# 9       1175.4372         Unit            non-food
# 10         0.3473           KG  cereals and tubers
# 11         0.2753           KG  cereals and tubers
# 12         0.3847           KG  cereals and tubers
# 13      1602.8689         Unit            non-food
# 14         0.3176           KG  cereals and tubers
# 15         0.2813           KG  cereals and tubers
# 16         0.3323           KG  cereals and tubers
# 17      1255.5700         Unit            non-food
# 18      3180.6047         Unit            non-food
# 19      2120.4031         Unit            non-food
# 20         0.3314           KG  cereals and tubers
# 21         0.1936           KG  cereals and tubers
# 22         0.2095           KG  cereals and tubers
# 23      1272.2419         Unit            non-food
# 24         0.2860           KG  cereals and tubers
# 25         0.2612           KG  cereals and tubers
# 26         0.3407           KG  cereals and tubers
# 27      1484.2822         Unit            non-food
# 28         0.3270           KG  cereals and tubers
# 29         0.2593           KG  cereals and tubers
# 30         0.3473           KG  cereals and tubers
# 31      1590.3023         Unit            non-food
# 32         0.3533           KG  cereals and tubers
# 33         0.2822           KG  cereals and tubers
# 34         0.3261           KG  cereals and tubers
# 35      1272.2313         Unit            non-food
# 36      1055.0656            L            non-food
# 37      2453.0274         Unit            non-food
# 38       722.7199            L            non-food
# 39      2110.1311         Unit            non-food
# 40         0.3406           KG  cereals and tubers
# 41         0.1861           KG  cereals and tubers
# 42         0.2159           KG  cereals and tubers
# 43       337.6210            L            non-food
# 44      1266.0787         Unit            non-food
# 45         0.2482           KG  cereals and tubers
# 46         0.2473           KG  cereals and tubers
# 47         0.3007           KG  cereals and tubers
# 48       254.7983            L            non-food
# 49      1477.0918         Unit            non-food

# %%
#Replacing category with category_mode

df_food_removed['category']=df_food_removed['category_mode']

# %%
#Checking the result

df_food_removed.groupby('product_name')['category'].nunique().sort_values(ascending=False) #perfect!
# Out:
# product_name
# Alcohol          1
# Potato Leaves    1
# Peas             1
# Pen              1
# Pencil           1
#                 ..
# Fuel             1
# Gari             1
# Garlic           1
# Ghee             1
# Zucchini         1
# Name: category, Length: 202, dtype: int64

# %%
#Removing the category_mode column

df_food_removed.drop(columns=['category_mode','measure_mode'], inplace=True)

# %%
# Fixing different fule types issue. Disel and kerosine are recorded as one product, I will fix that

df_food_removed['commodity'][df_food_removed['commodity'].str.contains('Fuel')].value_counts()
# Out:
# Fuel (diesel)                                35670
# Fuel (petrol-gasoline)                       24929
# Fuel (gas)                                   12573
# Fuel (kerosene)                               4360
# Fuel (petrol-gasoline, 95 octane)             3316
# Fuel (diesel, transport, parallel market)     2602
# Fuel (gas, parallel market)                   2501
# Fuel (diesel, heating, parallel market)       2187
# Fuel (Super Petrol)                           1902
# Fuel (LPG)                                    1350
# Fuel (petrol-gasoline, 92 octane)             1342
# Fuel (diesel, parallel market)                 781
# Fuel (petrol-gasoline, parallel market)        762
# Fuel (kerosene, paraffin)                      182
# Fuel (petrol)                                  155
# Name: commodity, dtype: int64

# %%
df_food_removed.loc[df_food_removed['commodity'].str.contains('diesel'), 'product_name']='Diesel'
df_food_removed.loc[df_food_removed['commodity'].str.contains('petrol'), 'product_name']='Petrol'   
df_food_removed.loc[df_food_removed['commodity'].str.contains('gas'), 'product_name']='Gas' 
df_food_removed.loc[df_food_removed['commodity'].str.contains('kerosene'), 'product_name']='Kerosene'

# %% [markdown]
# ### Handling multiple currencies

# %%
#Checking if only one local currency is used per country

df_food_removed.groupby('iso')['currency'].nunique().sort_values(ascending=False) #6 countries have more than one currency
# Out:
# iso
# ZWE    2
# HND    2
# PAN    2
# SOM    2
# NIC    2
#       ..
# GEO    1
# GAB    1
# FJI    1
# ETH    1
# LBN    1
# Name: currency, Length: 99, dtype: int64

# %%
# Local currency in ZWE was changed from ZWD to ZWL with with the exchange rate 1 to 10in25th

df_food_removed[df_food_removed['iso']=='ZWE'] #until the currency way changed, the prices were recorded in USD
# Out:
#               date                market   latitude  longitude  \
# 2704689 2010-01-15                Kombai        NaN        NaN
# 2704690 2010-01-15               Mandava        NaN        NaN
# 2704691 2010-01-15               Mucheke        NaN        NaN
# 2704692 2010-01-15            Murombedzi        NaN        NaN
# 2704693 2010-01-15  Renkini Bus Terminus        NaN        NaN
# ...            ...                   ...        ...        ...
# 2726296 2023-01-15    Nkayi Growth Point -18.999158  28.898316
# 2726297 2023-01-15    Nkayi Growth Point -18.999158  28.898316
# 2726298 2023-01-15    Nkayi Growth Point -18.999158  28.898316
# 2726299 2023-01-15    Nkayi Growth Point -18.999158  28.898316
# 2726300 2023-01-15    Nkayi Growth Point -18.999158  28.898316
#
#                    category        commodity    unit pricetype currency  \
# 2704689  cereals and tubers            Maize      KG    Retail      USD
# 2704690  cereals and tubers            Maize      KG    Retail      USD
# 2704691  cereals and tubers            Maize      KG    Retail      USD
# 2704692  cereals and tubers            Maize      KG    Retail      USD
# 2704693  cereals and tubers            Maize      KG    Retail      USD
# ...                     ...              ...     ...       ...      ...
# 2726296            non-food    Handwash soap   250 G    Retail      ZWL
# 2726297            non-food     Laundry soap      KG    Retail      ZWL
# 2726298            non-food       Toothpaste  100 ML    Retail      ZWL
# 2726299        oil and fats  Oil (vegetable)       L    Retail      ZWL
# 2726300     pulses and nuts    Beans (sugar)      KG    Retail      ZWL
#
#            price  usdprice  iso measure_unit   product_name  price_unit  \
# 2704689     0.26    0.2571  ZWE           KG          Maize        0.26
# 2704690     0.26    0.2571  ZWE           KG          Maize        0.26
# 2704691     0.31    0.3143  ZWE           KG          Maize        0.31
# 2704692     0.23    0.2286  ZWE           KG          Maize        0.23
# 2704693     0.31    0.3143  ZWE           KG          Maize        0.31
# ...          ...       ...  ...          ...            ...         ...
# 2726296   280.00    0.3834  ZWE           KG  Handwash soap     1120.00
# 2726297  1408.00    1.9280  ZWE           KG   Laundry soap     1408.00
# 2726298  1400.00    1.9170  ZWE            L     Toothpaste    14000.00
# 2726299  2000.00    2.7386  ZWE            L            Oil     2000.00
# 2726300  1600.00    2.1909  ZWE           KG          Beans     1600.00
#
#          usdprice_unit
# 2704689         0.2571
# 2704690         0.2571
# 2704691         0.3143
# 2704692         0.2286
# 2704693         0.3143
# ...                ...
# 2726296         1.5336
# 2726297         1.9280
# 2726298        19.1700
# 2726299         2.7386
# 2726300         2.1909
#
# [21612 rows x 16 columns]

# %%
# To unify the currency, I'm converting ZWL - new currency to USD 
df_food_removed.loc[(df_food_removed['iso']=='ZWE')&(df_food_removed['currency']=='ZWL'), 'price_unit']=df_food_removed['usdprice_unit']

# %%
# Changing currency to USD
df_food_removed.loc[(df_food_removed['iso']=='ZWE')&(df_food_removed['currency']=='ZWL'), 'currency']='USD'

# %%
# Local currency in Somalia is abbreviated as SOS

df_food_removed[df_food_removed['iso']=='SOM']
# Out:
#               date    market  latitude  longitude               category  \
# 2132135 1995-01-15   Bakaara  2.048031   45.32000     cereals and tubers
# 2132136 1995-02-15   Bakaara  2.048031   45.32000     cereals and tubers
# 2132137 1995-03-15   Bakaara  2.048031   45.32000     cereals and tubers
# 2132138 1995-04-15   Bakaara  2.048031   45.32000     cereals and tubers
# 2132139 1995-05-15   Bakaara  2.048031   45.32000     cereals and tubers
# ...            ...       ...       ...        ...                    ...
# 2155497 2023-07-15  Hargeysa  9.559750   44.06678               non-food
# 2155498 2023-07-15  Hargeysa  9.559750   44.06678               non-food
# 2155499 2023-07-15  Hargeysa  9.559750   44.06678           oil and fats
# 2155500 2023-07-15  Hargeysa  9.559750   44.06678        pulses and nuts
# 2155501 2023-07-15  Hargeysa  9.559750   44.06678  vegetables and fruits
#
#                          commodity     unit pricetype currency    price  \
# 2132135              Sorghum (red)       KG    Retail      SOS    700.0
# 2132136              Sorghum (red)       KG    Retail      SOS    525.0
# 2132137              Sorghum (red)       KG    Retail      SOS    600.0
# 2132138              Sorghum (red)       KG    Retail      SOS    900.0
# 2132139              Sorghum (red)       KG    Retail      SOS   1025.0
# ...                            ...      ...       ...      ...      ...
# 2155497              Exchange rate  USD/LCU    Retail      SLS   8600.0
# 2155498              Fuel (diesel)        L    Retail      SLS   7500.0
# 2155499  Oil (vegetable, imported)        L    Retail      SLS  15500.0
# 2155500                    Cowpeas       KG    Retail      SLS  18000.0
# 2155501                     Onions       KG    Retail      SLS   9250.0
#
#          usdprice  iso measure_unit   product_name  price_unit  usdprice_unit
# 2132135    0.0850  SOM           KG        Sorghum       700.0         0.0850
# 2132136    0.0628  SOM           KG        Sorghum       525.0         0.0628
# 2132137    0.0708  SOM           KG        Sorghum       600.0         0.0708
# 2132138    0.1046  SOM           KG        Sorghum       900.0         0.1046
# 2132139    0.1174  SOM           KG        Sorghum      1025.0         0.1174
# ...           ...  ...          ...            ...         ...            ...
# 2155497       NaN  SOM         Unit  Exchange rate      8600.0            NaN
# 2155498       NaN  SOM            L         Diesel      7500.0            NaN
# 2155499       NaN  SOM            L            Oil     15500.0            NaN
# 2155500       NaN  SOM           KG        Cowpeas     18000.0            NaN
# 2155501       NaN  SOM           KG         Onions      9250.0            NaN
#
# [23367 rows x 16 columns]

# %%
# Changing currency to SOS
df_food_removed.loc[(df_food_removed['iso']=='SOM')&(df_food_removed['currency']=='SLS'), 'currency']='SOS'

# %%
#MWK is official currency in Malawi. It's unclear why SOS was used to record the values
df_food_removed[df_food_removed['iso']=='MWI']
# Out:
#               date            market   latitude  longitude  \
# 1693836 1990-10-15  National Average        NaN        NaN
# 1693837 1990-10-15  National Average        NaN        NaN
# 1693838 1991-08-15  National Average        NaN        NaN
# 1693839 1991-08-15  National Average        NaN        NaN
# 1693840 1992-06-15  National Average        NaN        NaN
# ...            ...               ...        ...        ...
# 1712131 2022-09-15          Luchenza -16.007655  35.311648
# 1712132 2022-09-15       Thyolo Boma -16.067166  35.145327
# 1712133 2022-09-15        Chinamwali -15.379600  35.360822
# 1712134 2022-09-15           Songani -15.317222  35.393137
# 1712135 2022-09-15           Thondwe -15.488345  35.235301
#
#                    category                  commodity unit pricetype  \
# 1693836            non-food              Fuel (diesel)    L    Retail
# 1693837            non-food  Fuel (kerosene, paraffin)    L    Retail
# 1693838            non-food              Fuel (diesel)    L    Retail
# 1693839            non-food  Fuel (kerosene, paraffin)    L    Retail
# 1693840            non-food              Fuel (diesel)    L    Retail
# ...                     ...                        ...  ...       ...
# 1712131  cereals and tubers                      Maize   KG    Retail
# 1712132  cereals and tubers                      Maize   KG    Retail
# 1712133  cereals and tubers                      Maize   KG    Retail
# 1712134  cereals and tubers                      Maize   KG    Retail
# 1712135  cereals and tubers                      Maize   KG    Retail
#
#         currency   price  usdprice  iso measure_unit product_name  price_unit  \
# 1693836      MWK    1.90    0.7162  MWI            L       Diesel        1.90
# 1693837      MWK    1.22    0.4599  MWI            L     Kerosene        1.22
# 1693838      MWK    2.00    0.6893  MWI            L       Diesel        2.00
# 1693839      MWK    1.22    0.4204  MWI            L     Kerosene        1.22
# 1693840      MWK    2.58    0.7097  MWI            L       Diesel        2.58
# ...          ...     ...       ...  ...          ...          ...         ...
# 1712131      MWK  360.00    0.3512  MWI           KG        Maize      360.00
# 1712132      MWK  355.00    0.3463  MWI           KG        Maize      355.00
# 1712133      MWK  351.50    0.3429  MWI           KG        Maize      351.50
# 1712134      MWK  354.00    0.3453  MWI           KG        Maize      354.00
# 1712135      MWK  333.50    0.3253  MWI           KG        Maize      333.50
#
#          usdprice_unit
# 1693836         0.7162
# 1693837         0.4599
# 1693838         0.6893
# 1693839         0.4204
# 1693840         0.7097
# ...                ...
# 1712131         0.3512
# 1712132         0.3463
# 1712133         0.3429
# 1712134         0.3453
# 1712135         0.3253
#
# [18300 rows x 16 columns]

# %%
# To avoid the confusion, the prices will be changed to USD

df_food_removed.loc[df_food_removed['iso']=='MWI', 'price_unit']=df_food_removed['usdprice_unit']

# %%
# Changing currency to USD

df_food_removed.loc[df_food_removed['iso']=='MWI', 'currency']='USD'

# %%
# In Panama wholesale prices are recorded in USD, which really complicates the conversion. For now I will replace currency with PAB and prices in local currency with nan

df_food_removed[(df_food_removed['iso']=='PAN')&(df_food_removed['currency']=='USD')]
# Out:
#               date            market  latitude  longitude            category  \
# 1848732 2007-09-15  National Average       NaN        NaN  cereals and tubers
# 1848733 2007-09-15  National Average       NaN        NaN  cereals and tubers
# 1848745 2007-10-15  National Average       NaN        NaN  cereals and tubers
# 1848755 2007-11-15  National Average       NaN        NaN  cereals and tubers
# 1848756 2007-11-15  National Average       NaN        NaN  cereals and tubers
# ...            ...               ...       ...        ...                 ...
# 1849800 2015-03-15  National Average       NaN        NaN  cereals and tubers
# 1849833 2015-06-15  National Average       NaN        NaN  cereals and tubers
# 1849834 2015-06-15  National Average       NaN        NaN  cereals and tubers
# 1849846 2015-07-15  National Average       NaN        NaN  cereals and tubers
# 1849847 2015-07-15  National Average       NaN        NaN  cereals and tubers
#
#                    commodity unit  pricetype currency   price  usdprice  iso  \
# 1848732       Maize (yellow)   MT  Wholesale      USD  304.35  304.3500  PAN
# 1848733  Rice (milled 80-20)   MT  Wholesale      USD  739.13  739.1300  PAN
# 1848745  Rice (milled 80-20)   MT  Wholesale      USD  739.13  739.1300  PAN
# 1848755       Maize (yellow)   MT  Wholesale      USD  369.57  369.5667  PAN
# 1848756  Rice (milled 80-20)   MT  Wholesale      USD  739.13  739.1300  PAN
# ...                      ...  ...        ...      ...     ...       ...  ...
# 1849800  Rice (milled 80-20)   MT  Wholesale      USD  847.83  847.8300  PAN
# 1849833       Maize (yellow)   MT  Wholesale      USD  524.71  524.7100  PAN
# 1849834  Rice (milled 80-20)   MT  Wholesale      USD  841.02  841.0167  PAN
# 1849846       Maize (yellow)   MT  Wholesale      USD  522.61  522.6100  PAN
# 1849847  Rice (milled 80-20)   MT  Wholesale      USD  837.61  837.6100  PAN
#
#         measure_unit product_name  price_unit  usdprice_unit
# 1848732           KG        Maize     0.30435       0.304350
# 1848733           KG         Rice     0.73913       0.739130
# 1848745           KG         Rice     0.73913       0.739130
# 1848755           KG        Maize     0.36957       0.369567
# 1848756           KG         Rice     0.73913       0.739130
# ...              ...          ...         ...            ...
# 1849800           KG         Rice     0.84783       0.847830
# 1849833           KG        Maize     0.52471       0.524710
# 1849834           KG         Rice     0.84102       0.841017
# 1849846           KG        Maize     0.52261       0.522610
# 1849847           KG         Rice     0.83761       0.837610
#
# [158 rows x 16 columns]

# %%
# Changing price in local currency to NaN

df_food_removed.loc[(df_food_removed['iso']=='PAN')&(df_food_removed['currency']=='USD'), 'price_unit']=np.nan

# %%
# Changing currency to PAB

df_food_removed.loc[df_food_removed['iso']=='PAN', 'currency']='PAB'

# %%
# In Nicaragua retail prices are recorded in USD, which really complicates the conversion. For now I will replace currency with PAB and prices in local currency with nan

df_food_removed[(df_food_removed['iso']=='NIC')&(df_food_removed['currency']=='USD')]
# Out:
#               date            market  latitude  longitude  \
# 1809315 2010-01-15  National Average       NaN        NaN
# 1809316 2010-01-15  National Average       NaN        NaN
# 1809317 2010-01-15  National Average       NaN        NaN
# 1809318 2010-01-15  National Average       NaN        NaN
# 1809337 2010-02-15  National Average       NaN        NaN
# ...            ...               ...       ...        ...
# 1815934 2022-04-15  National Average       NaN        NaN
# 1815935 2022-04-15  National Average       NaN        NaN
# 1815936 2022-04-15  National Average       NaN        NaN
# 1815937 2022-04-15  National Average       NaN        NaN
# 1815938 2022-04-15  National Average       NaN        NaN
#
#                       category         commodity   unit pricetype currency  \
# 1809315     cereals and tubers  Tortilla (maize)  Pound    Retail      USD
# 1809316    meat, fish and eggs      Fish (fresh)  Pound    Retail      USD
# 1809317    meat, fish and eggs       Meat (beef)  Pound    Retail      USD
# 1809318    meat, fish and eggs       Meat (pork)  Pound    Retail      USD
# 1809337     cereals and tubers  Tortilla (maize)  Pound    Retail      USD
# ...                        ...               ...    ...       ...      ...
# 1815934  vegetables and fruits           Oranges  Pound    Retail      USD
# 1815935  vegetables and fruits   Peppers (sweet)  Pound    Retail      USD
# 1815936  vegetables and fruits         Plantains  Pound    Retail      USD
# 1815937  vegetables and fruits          Squashes  Pound    Retail      USD
# 1815938  vegetables and fruits          Tomatoes  Pound    Retail      USD
#
#          price  usdprice  iso measure_unit product_name  price_unit  \
# 1809315   0.44    0.4386  NIC           KG     Tortilla    0.977778
# 1809316   1.95    1.9473  NIC           KG         Fish    4.333333
# 1809317   1.82    1.8238  NIC           KG         Meat    4.044444
# 1809318   2.10    2.0986  NIC           KG         Meat    4.666667
# 1809337   0.45    0.4483  NIC           KG     Tortilla    1.000000
# ...        ...       ...  ...          ...          ...         ...
# 1815934   0.29    0.2900  NIC           KG      Oranges    0.644444
# 1815935   1.07    1.0700  NIC           KG      Peppers    2.377778
# 1815936   0.31    0.3100  NIC           KG    Plantains    0.688889
# 1815937   0.25    0.2500  NIC           KG     Squashes    0.555556
# 1815938   0.55    0.5500  NIC           KG     Tomatoes    1.222222
#
#          usdprice_unit
# 1809315       0.974667
# 1809316       4.327333
# 1809317       4.052889
# 1809318       4.663556
# 1809337       0.996222
# ...                ...
# 1815934       0.644444
# 1815935       2.377778
# 1815936       0.688889
# 1815937       0.555556
# 1815938       1.222222
#
# [5090 rows x 16 columns]

# %%
# Changing price in local currency to NaN

df_food_removed.loc[(df_food_removed['iso']=='NIC')&(df_food_removed['currency']=='USD'), 'price_unit']=np.nan

# %%
# Changing currency to NIO

df_food_removed.loc[df_food_removed['iso']=='NIC', 'currency']='NIO'

# %%
# In Honduras wholesale prices are recorded in USD, which really complicates the conversion. For now I will replace currency with local and prices in local currency with nan

df_food_removed[(df_food_removed['iso']=='HND')&(df_food_removed['currency']=='USD')]
# Out:
#              date            market  latitude  longitude            category  \
# 772244 2007-07-15  National Average       NaN        NaN  cereals and tubers
# 772245 2007-07-15  National Average       NaN        NaN     pulses and nuts
# 772252 2007-08-15  National Average       NaN        NaN  cereals and tubers
# 772253 2007-08-15  National Average       NaN        NaN     pulses and nuts
# 772260 2007-09-15  National Average       NaN        NaN  cereals and tubers
# ...           ...               ...       ...        ...                 ...
# 773621 2019-10-15  National Average       NaN        NaN  cereals and tubers
# 773622 2019-10-15  National Average       NaN        NaN     pulses and nuts
# 773629 2019-11-15  National Average       NaN        NaN  cereals and tubers
# 773630 2019-11-15  National Average       NaN        NaN  cereals and tubers
# 773631 2019-11-15  National Average       NaN        NaN     pulses and nuts
#
#                   commodity unit  pricetype currency    price   usdprice  iso  \
# 772244      Sorghum (white)   MT  Wholesale      USD   597.83   597.8260  HND
# 772245          Beans (red)   MT  Wholesale      USD  1358.70  1358.6960  HND
# 772252      Sorghum (white)   MT  Wholesale      USD   652.17   652.1740  HND
# 772253          Beans (red)   MT  Wholesale      USD  1739.13  1739.1305  HND
# 772260  Rice (milled 80-20)   MT  Wholesale      USD   636.09   636.0900  HND
# ...                     ...  ...        ...      ...      ...        ...  ...
# 773621  Rice (milled 80-20)   MT  Wholesale      USD   706.00   706.0000  HND
# 773622          Beans (red)   MT  Wholesale      USD  1007.00  1007.0000  HND
# 773629        Maize (white)   MT  Wholesale      USD   338.00   338.0000  HND
# 773630  Rice (milled 80-20)   MT  Wholesale      USD   703.00   703.0000  HND
# 773631          Beans (red)   MT  Wholesale      USD  1046.00  1046.0000  HND
#
#        measure_unit product_name  price_unit  usdprice_unit
# 772244           KG      Sorghum     0.59783       0.597826
# 772245           KG        Beans     1.35870       1.358696
# 772252           KG      Sorghum     0.65217       0.652174
# 772253           KG        Beans     1.73913       1.739130
# 772260           KG         Rice     0.63609       0.636090
# ...             ...          ...         ...            ...
# 773621           KG         Rice     0.70600       0.706000
# 773622           KG        Beans     1.00700       1.007000
# 773629           KG        Maize     0.33800       0.338000
# 773630           KG         Rice     0.70300       0.703000
# 773631           KG        Beans     1.04600       1.046000
#
# [611 rows x 16 columns]

# %%
# Changing price in local currency to NaN

df_food_removed.loc[(df_food_removed['iso']=='HND')&(df_food_removed['currency']=='USD'), 'price_unit']=np.nan

# %%
# Changing currency to NIO

df_food_removed.loc[df_food_removed['iso']=='HND', 'currency']='HNL'

# %%
df_food_removed.shape
# Out:
# (2726301, 16)

# %% [markdown]
# ### Some data sets contain exchange rate as one of the commodities, I will isolate it and use for price conversion

# %%
df_exchange_rate=df_food_removed[df_food_removed['product_name']=='Exchange rate']

# %%
df_earnings=df_food_removed[df_food_removed['product_name']=='Wage']
df_earnings
# Out:
#               date             market   latitude  longitude  category  \
# 0       2000-01-15           Fayzabad  37.116638  70.580022  non-food
# 1       2000-01-15              Mazar  36.725116  67.109571  non-food
# 5       2000-01-15              Hirat  34.346944  62.198333  non-food
# 9       2000-01-15              Kabul  34.516667  69.183333  non-food
# 13      2000-01-15           Kandahar  31.612500  65.709444  non-food
# ...            ...                ...        ...        ...       ...
# 2657459 2023-07-15         Attaq Town  14.801087  45.719959  non-food
# 2657477 2023-07-15  Soqatra (Hudaibo)  12.650000  54.033333  non-food
# 2657478 2023-07-15  Soqatra (Hudaibo)  12.650000  54.033333  non-food
# 2657494 2023-07-15          Taiz City  13.580000  44.020000  non-food
# 2657495 2023-07-15          Taiz City  13.580000  44.020000  non-food
#
#                                              commodity unit pricetype  \
# 0        Wage (non-qualified labour, non-agricultural)  Day    Retail
# 1        Wage (non-qualified labour, non-agricultural)  Day    Retail
# 5        Wage (non-qualified labour, non-agricultural)  Day    Retail
# 9        Wage (non-qualified labour, non-agricultural)  Day    Retail
# 13       Wage (non-qualified labour, non-agricultural)  Day    Retail
# ...                                                ...  ...       ...
# 2657459                        Wage (qualified labour)  Day    Retail
# 2657477                    Wage (non-qualified labour)  Day    Retail
# 2657478                        Wage (qualified labour)  Day    Retail
# 2657494                    Wage (non-qualified labour)  Day    Retail
# 2657495                        Wage (qualified labour)  Day    Retail
#
#         currency     price   usdprice  iso measure_unit product_name  \
# 0            AFN  150000.0  3205.7378  AFG         Unit         Wage
# 1            AFN  100000.0  2137.1586  AFG         Unit         Wage
# 5            AFN   60000.0  1282.2951  AFG         Unit         Wage
# 9            AFN   55000.0  1175.4372  AFG         Unit         Wage
# 13           AFN   75000.0  1602.8689  AFG         Unit         Wage
# ...          ...       ...        ...  ...          ...          ...
# 2657459      YER   15000.0    10.7603  YEM         Unit         Wage
# 2657477      YER   15000.0    10.7603  YEM         Unit         Wage
# 2657478      YER   20000.0    14.3470  YEM         Unit         Wage
# 2657494      YER    8000.0     5.7388  YEM         Unit         Wage
# 2657495      YER   15000.0    10.7603  YEM         Unit         Wage
#
#          price_unit  usdprice_unit
# 0          150000.0      3205.7378
# 1          100000.0      2137.1586
# 5           60000.0      1282.2951
# 9           55000.0      1175.4372
# 13          75000.0      1602.8689
# ...             ...            ...
# 2657459     15000.0        10.7603
# 2657477     15000.0        10.7603
# 2657478     20000.0        14.3470
# 2657494      8000.0         5.7388
# 2657495     15000.0        10.7603
#
# [24196 rows x 16 columns]

# %%
df_exchange_rate.drop(columns=['pricetype','measure_unit','product_name','price_unit','usdprice_unit'],inplace=True)

# %%
df_exchange_rate.to_csv(os.path.join(path, 'wfp_exchange_rate.csv'))
df_exchange_rate.to_pickle(os.path.join(path, 'wfp_exchange_rate.pkl'))

# %%
df_exchange_rate.shape
# Out:
# (15600, 11)

# %%
df_earnings.to_pickle(os.path.join(path, 'wfp_wage_earning.pkl'))

# %%
df_earnings.shape
# Out:
# (24196, 16)

# %%
# Removing exchange rate data from the main dataframe

df_food_removed=df_food_removed[~df_food_removed['product_name'].isin(['Exchange rate','Wage'])]
df_food_removed.shape
# Out:
# (2686505, 16)

# %%
#Saving data at this stage

df_food_removed.to_pickle(os.path.join(path, 'all_products_prices_market_unaggregated.pkl'))

# %% [markdown]
# ### Next steps:
# - adding missing prices using exchange rate data
# - aggregating average price for the same product-day-market-country
# - merging the data with other datasets
# - adding country names
# - adding missing coordinates
